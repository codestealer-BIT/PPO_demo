# %%
import random
import gym
import numpy as np
import collections
from tqdm import tqdm
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
import rl_utils

# %%
class ReplayBuffer:
    ''' 经验回放池 '''
    def __init__(self, capacity):
        self.buffer = collections.deque(maxlen=capacity)  # 队列,先进先出

    def add(self, state, action, reward, next_state, done):  # 将数据加入buffer
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):  # 从buffer中采样数据,数量为batch_size
        transitions = random.sample(self.buffer, batch_size)
        state, action, reward, next_state, done = zip(*transitions)
        return np.array(state), action, reward, np.array(next_state), done

    def size(self):  # 目前buffer中数据的数量
        return len(self.buffer)

# %%
class Qnet(torch.nn.Module):
    ''' 只有一层隐藏层的Q网络 '''
    def __init__(self, state_dim, hidden_dim, action_dim):
        super(Qnet, self).__init__()
        self.fc1 = torch.nn.Linear(state_dim, hidden_dim)
        self.fc2 = torch.nn.Linear(hidden_dim, action_dim)

    def forward(self, x):
        x = F.relu(self.fc1(x))  # 隐藏层使用ReLU激活函数
        return self.fc2(x)

# %%
class DQN:
    ''' DQN算法 '''
    def __init__(self, state_dim, hidden_dim, action_dim, learning_rate, gamma,
                 epsilon, target_update, device):
        self.action_dim = action_dim
        self.q_net = Qnet(state_dim, hidden_dim,
                          self.action_dim).to(device)  # Q网络
        # 目标网络
        self.target_q_net = Qnet(state_dim, hidden_dim,
                                 self.action_dim).to(device)
        # 使用Adam优化器
        self.optimizer = torch.optim.Adam(self.q_net.parameters(),
                                          lr=learning_rate)
        self.gamma = gamma  # 折扣因子
        self.epsilon = epsilon  # epsilon-贪婪策略
        self.target_update = target_update  # 目标网络更新频率
        self.count = 0  # 计数器,记录更新次数
        self.device = device

    def take_action(self, state):  # epsilon-贪婪策略采取动作
        if np.random.random() < self.epsilon:
            action = np.random.randint(self.action_dim)
        else:
            state = torch.tensor([state], dtype=torch.float).to(self.device)
            action = self.q_net(state).argmax().item()
        return action

    def update(self, transition_dict):
        states = torch.tensor(transition_dict['states'],
                              dtype=torch.float).to(self.device)
        actions = torch.tensor(transition_dict['actions']).view(-1, 1).to(
            self.device)
        rewards = torch.tensor(transition_dict['rewards'],
                               dtype=torch.float).view(-1, 1).to(self.device)
        next_states = torch.tensor(transition_dict['next_states'],
                                   dtype=torch.float).to(self.device)
        dones = torch.tensor(transition_dict['dones'],
                             dtype=torch.float).view(-1, 1).to(self.device)

        q_values = self.q_net(states).gather(1, actions)  # Q值
        # 下个状态的最大Q值
        max_next_q_values = self.target_q_net(next_states).max(1)[0].view(
            -1, 1)
        q_targets = rewards + self.gamma * max_next_q_values * (1 - dones
                                                                )  # TD误差目标
        dqn_loss = torch.mean(F.mse_loss(q_values, q_targets))  # 均方误差损失函数
        self.optimizer.zero_grad()  # PyTorch中默认梯度会累积,这里需要显式将梯度置为0
        dqn_loss.backward()  # 反向传播更新参数
        self.optimizer.step()

        if self.count % self.target_update == 0:
            self.target_q_net.load_state_dict(
                self.q_net.state_dict())  # 更新目标网络
        self.count += 1

# %%
lr = 2e-3
num_episodes = 500
hidden_dim = 128
gamma = 0.98
epsilon = 0.01
target_update = 10
buffer_size = 10000
minimal_size = 500
batch_size = 64
device = torch.device("cuda") if torch.cuda.is_available() else torch.device(
    "cpu")

env_name = 'Pong-ram-v0'
env = gym.make(env_name)
random.seed(0)
np.random.seed(0)
env.seed(0)
torch.manual_seed(0)
replay_buffer = ReplayBuffer(buffer_size)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n
agent = DQN(state_dim, hidden_dim, action_dim, lr, gamma, epsilon,
            target_update, device)

# %%
return_list = []
for i in range(3000):
    with tqdm(total=int(num_episodes / 10), desc='Iteration %d' % i) as pbar:
        for i_episode in range(int(num_episodes / 10)):
            episode_return = 0
            state = env.reset()
            state=state.astype(np.float32)
            state/=255
            done = False
            while not done:
                
                action = agent.take_action(state)
                next_state, reward, done, _ = env.step(action)
                next_state=next_state.astype(np.float32)
                next_state/=255
                replay_buffer.add(state, action, reward, next_state, done)
                state = next_state
                episode_return += reward
                # 当buffer数据的数量超过一定值后,才进行Q网络训练
                if replay_buffer.size() > minimal_size:
                    b_s, b_a, b_r, b_ns, b_d = replay_buffer.sample(batch_size)
                    transition_dict = {
                        'states': b_s,
                        'actions': b_a,
                        'next_states': b_ns,
                        'rewards': b_r,
                        'dones': b_d
                    }
                    agent.update(transition_dict)
            return_list.append(episode_return)
            if (i_episode + 1) % 10 == 0:
                pbar.set_postfix({
                    'episode':
                    '%d' % (num_episodes / 10 * i + i_episode + 1),
                    'return':
                    '%.3f' % np.mean(return_list[-10:])
                })
            pbar.update(1)

# Iteration 0: 100%|██████████| 50/50 [00:00<00:00, 764.86it/s, episode=50,
# return=9.300]
# Iteration 1: 100%|██████████| 50/50 [00:04<00:00, 10.66it/s, episode=100,
# return=12.300]
# Iteration 2: 100%|██████████| 50/50 [00:24<00:00,  2.05it/s, episode=150,
# return=123.000]
# Iteration 3: 100%|██████████| 50/50 [01:25<00:00,  1.71s/it, episode=200,
# return=153.600]
# Iteration 4: 100%|██████████| 50/50 [01:30<00:00,  1.80s/it, episode=250,
# return=180.500]
# Iteration 5: 100%|██████████| 50/50 [01:24<00:00,  1.68s/it, episode=300,
# return=185.000]
# Iteration 6: 100%|██████████| 50/50 [01:32<00:00,  1.85s/it, episode=350,
# return=193.900]
# Iteration 7: 100%|██████████| 50/50 [01:31<00:00,  1.84s/it, episode=400,
# return=196.600]
# Iteration 8: 100%|██████████| 50/50 [01:33<00:00,  1.88s/it, episode=450,
# return=193.800]
# Iteration 9: 100%|██████████| 50/50 [01:34<00:00,  1.88s/it, episode=500,
# return=200.000]
# Out:
# Iteration 0:   0%|                                       | 0/50 [00:00<?, ?it/s]/var/folders/22/8h12wpln0_v21shpwshl6hpr0000ks/T/ipykernel_7134/725080296.py:24: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:281.)
#   state = torch.tensor([state], dtype=torch.float).to(self.device)
# Iteration 0: 100%|██| 50/50 [00:38<00:00,  1.30it/s, episode=50, return=-20.300]
# Iteration 1: 100%|█| 50/50 [00:34<00:00,  1.47it/s, episode=100, return=-20.900]
# Iteration 2: 100%|█| 50/50 [00:44<00:00,  1.13it/s, episode=150, return=-20.700]
# Iteration 3: 100%|█| 50/50 [00:40<00:00,  1.22it/s, episode=200, return=-20.800]
# Iteration 4: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=250, return=-20.500]
# Iteration 5: 100%|█| 50/50 [00:35<00:00,  1.43it/s, episode=300, return=-21.000]
# Iteration 6: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=350, return=-20.800]
# Iteration 7: 100%|█| 50/50 [00:39<00:00,  1.28it/s, episode=400, return=-20.500]
# Iteration 8: 100%|█| 50/50 [00:38<00:00,  1.31it/s, episode=450, return=-20.500]
# Iteration 9: 100%|█| 50/50 [00:42<00:00,  1.18it/s, episode=500, return=-20.600]
# Iteration 10: 100%|█| 50/50 [00:38<00:00,  1.30it/s, episode=550, return=-20.300
# Iteration 11: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=600, return=-20.900
# Iteration 12: 100%|█| 50/50 [00:38<00:00,  1.30it/s, episode=650, return=-20.600
# Iteration 13: 100%|█| 50/50 [00:40<00:00,  1.24it/s, episode=700, return=-20.800
# Iteration 14: 100%|█| 50/50 [00:37<00:00,  1.32it/s, episode=750, return=-20.700
# Iteration 15: 100%|█| 50/50 [00:37<00:00,  1.32it/s, episode=800, return=-20.900
# Iteration 16: 100%|█| 50/50 [00:38<00:00,  1.28it/s, episode=850, return=-20.800
# Iteration 17: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=900, return=-20.400
# Iteration 18: 100%|█| 50/50 [00:38<00:00,  1.31it/s, episode=950, return=-20.900
# Iteration 19: 100%|█| 50/50 [00:38<00:00,  1.29it/s, episode=1000, return=-20.50
# Iteration 20: 100%|█| 50/50 [00:38<00:00,  1.29it/s, episode=1050, return=-20.70
# Iteration 21: 100%|█| 50/50 [00:39<00:00,  1.27it/s, episode=1100, return=-20.90
# Iteration 22: 100%|█| 50/50 [00:37<00:00,  1.32it/s, episode=1150, return=-20.50
# Iteration 23: 100%|█| 50/50 [00:37<00:00,  1.32it/s, episode=1200, return=-20.50
# Iteration 24: 100%|█| 50/50 [00:37<00:00,  1.33it/s, episode=1250, return=-20.60
# Iteration 25: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=1300, return=-20.40
# Iteration 26: 100%|█| 50/50 [00:38<00:00,  1.31it/s, episode=1350, return=-20.70
# Iteration 27: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=1400, return=-20.40
# Iteration 28: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=1450, return=-20.60
# Iteration 29: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=1500, return=-20.30
# Iteration 30: 100%|█| 50/50 [00:35<00:00,  1.39it/s, episode=1550, return=-20.30
# Iteration 31: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=1600, return=-20.40
# Iteration 32: 100%|█| 50/50 [00:34<00:00,  1.47it/s, episode=1650, return=-20.50
# Iteration 33: 100%|█| 50/50 [00:33<00:00,  1.48it/s, episode=1700, return=-20.90
# Iteration 34: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=1750, return=-20.60
# Iteration 35: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=1800, return=-20.40
# Iteration 36: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=1850, return=-20.50
# Iteration 37: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=1900, return=-20.70
# Iteration 38: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=1950, return=-20.50
# Iteration 39: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=2000, return=-20.80
# Iteration 40: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=2050, return=-20.20
# Iteration 41: 100%|█| 50/50 [00:34<00:00,  1.43it/s, episode=2100, return=-20.60
# Iteration 42: 100%|█| 50/50 [00:34<00:00,  1.46it/s, episode=2150, return=-20.70
# Iteration 43: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=2200, return=-20.80
# Iteration 44: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=2250, return=-20.70
# Iteration 45: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=2300, return=-20.90
# Iteration 46: 100%|█| 50/50 [00:37<00:00,  1.35it/s, episode=2350, return=-20.30
# Iteration 47: 100%|█| 50/50 [00:38<00:00,  1.30it/s, episode=2400, return=-20.50
# Iteration 48: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=2450, return=-20.80
# Iteration 49: 100%|█| 50/50 [00:37<00:00,  1.35it/s, episode=2500, return=-20.70
# Iteration 50: 100%|█| 50/50 [00:35<00:00,  1.39it/s, episode=2550, return=-20.50
# Iteration 51: 100%|█| 50/50 [00:38<00:00,  1.31it/s, episode=2600, return=-20.60
# Iteration 52: 100%|█| 50/50 [00:34<00:00,  1.45it/s, episode=2650, return=-20.30
# Iteration 53: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=2700, return=-20.70
# Iteration 54: 100%|█| 50/50 [00:37<00:00,  1.33it/s, episode=2750, return=-20.80
# Iteration 55: 100%|█| 50/50 [00:38<00:00,  1.31it/s, episode=2800, return=-20.60
# Iteration 56: 100%|█| 50/50 [00:36<00:00,  1.35it/s, episode=2850, return=-20.80
# Iteration 57: 100%|█| 50/50 [00:35<00:00,  1.39it/s, episode=2900, return=-20.70
# Iteration 58: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=2950, return=-20.40
# Iteration 59: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=3000, return=-20.70
# Iteration 60: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=3050, return=-20.70
# Iteration 61: 100%|█| 50/50 [00:34<00:00,  1.43it/s, episode=3100, return=-20.80
# Iteration 62: 100%|█| 50/50 [00:38<00:00,  1.29it/s, episode=3150, return=-20.50
# Iteration 63: 100%|█| 50/50 [00:36<00:00,  1.35it/s, episode=3200, return=-20.60
# Iteration 64: 100%|█| 50/50 [00:34<00:00,  1.43it/s, episode=3250, return=-20.70
# Iteration 65: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=3300, return=-20.40
# Iteration 66: 100%|█| 50/50 [00:35<00:00,  1.43it/s, episode=3350, return=-20.50
# Iteration 67: 100%|█| 50/50 [00:34<00:00,  1.45it/s, episode=3400, return=-20.40
# Iteration 68: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=3450, return=-20.50
# Iteration 69: 100%|█| 50/50 [00:34<00:00,  1.46it/s, episode=3500, return=-20.50
# Iteration 70: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=3550, return=-20.50
# Iteration 71: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=3600, return=-20.70
# Iteration 72: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=3650, return=-20.30
# Iteration 73: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=3700, return=-20.60
# Iteration 74: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=3750, return=-20.70
# Iteration 75: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=3800, return=-20.40
# Iteration 76: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=3850, return=-20.00
# Iteration 77: 100%|█| 50/50 [00:34<00:00,  1.44it/s, episode=3900, return=-20.90
# Iteration 78: 100%|█| 50/50 [00:36<00:00,  1.39it/s, episode=3950, return=-20.70
# Iteration 79: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=4000, return=-20.90
# Iteration 80: 100%|█| 50/50 [00:37<00:00,  1.32it/s, episode=4050, return=-20.70
# Iteration 81: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=4100, return=-20.60
# Iteration 82: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=4150, return=-20.80
# Iteration 83: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=4200, return=-20.60
# Iteration 84: 100%|█| 50/50 [00:34<00:00,  1.44it/s, episode=4250, return=-20.50
# Iteration 85: 100%|█| 50/50 [00:41<00:00,  1.20it/s, episode=4300, return=-20.60
# Iteration 86: 100%|█| 50/50 [00:45<00:00,  1.09it/s, episode=4350, return=-20.70
# Iteration 87: 100%|█| 50/50 [00:37<00:00,  1.35it/s, episode=4400, return=-20.60
# Iteration 88: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=4450, return=-20.70
# Iteration 89: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=4500, return=-20.40
# Iteration 90: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=4550, return=-20.60
# Iteration 91: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=4600, return=-20.60
# Iteration 92: 100%|█| 50/50 [00:34<00:00,  1.45it/s, episode=4650, return=-20.70
# Iteration 93: 100%|█| 50/50 [00:35<00:00,  1.39it/s, episode=4700, return=-20.80
# Iteration 94: 100%|█| 50/50 [00:33<00:00,  1.48it/s, episode=4750, return=-20.70
# Iteration 95: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=4800, return=-20.50
# Iteration 96: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=4850, return=-20.60
# Iteration 97: 100%|█| 50/50 [00:34<00:00,  1.44it/s, episode=4900, return=-20.50
# Iteration 98: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=4950, return=-20.40
# Iteration 99: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=5000, return=-20.30
# Iteration 100: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=5050, return=-20.4
# Iteration 101: 100%|█| 50/50 [00:34<00:00,  1.44it/s, episode=5100, return=-20.5
# Iteration 102: 100%|█| 50/50 [00:35<00:00,  1.43it/s, episode=5150, return=-20.5
# Iteration 103: 100%|█| 50/50 [00:34<00:00,  1.43it/s, episode=5200, return=-20.2
# Iteration 104: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=5250, return=-20.5
# Iteration 105: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=5300, return=-20.8
# Iteration 106: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=5350, return=-20.2
# Iteration 107: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=5400, return=-20.3
# Iteration 108: 100%|█| 50/50 [00:34<00:00,  1.43it/s, episode=5450, return=-20.2
# Iteration 109: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=5500, return=-20.5
# Iteration 110: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=5550, return=-20.4
# Iteration 111: 100%|█| 50/50 [00:35<00:00,  1.43it/s, episode=5600, return=-20.5
# Iteration 112: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=5650, return=-20.8
# Iteration 113: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=5700, return=-20.9
# Iteration 114: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=5750, return=-20.8
# Iteration 115: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=5800, return=-20.3
# Iteration 116: 100%|█| 50/50 [00:37<00:00,  1.35it/s, episode=5850, return=-20.1
# Iteration 117: 100%|█| 50/50 [00:34<00:00,  1.44it/s, episode=5900, return=-20.4
# Iteration 118: 100%|█| 50/50 [00:34<00:00,  1.44it/s, episode=5950, return=-20.1
# Iteration 119: 100%|█| 50/50 [00:35<00:00,  1.43it/s, episode=6000, return=-20.8
# Iteration 120: 100%|█| 50/50 [00:34<00:00,  1.44it/s, episode=6050, return=-20.9
# Iteration 121: 100%|█| 50/50 [00:34<00:00,  1.44it/s, episode=6100, return=-20.7
# Iteration 122: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=6150, return=-20.6
# Iteration 123: 100%|█| 50/50 [00:34<00:00,  1.44it/s, episode=6200, return=-20.6
# Iteration 124: 100%|█| 50/50 [00:35<00:00,  1.43it/s, episode=6250, return=-20.7
# Iteration 125: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=6300, return=-20.4
# Iteration 126: 100%|█| 50/50 [00:35<00:00,  1.43it/s, episode=6350, return=-20.5
# Iteration 127: 100%|█| 50/50 [00:36<00:00,  1.39it/s, episode=6400, return=-20.2
# Iteration 128: 100%|█| 50/50 [00:34<00:00,  1.45it/s, episode=6450, return=-20.6
# Iteration 129: 100%|█| 50/50 [00:34<00:00,  1.46it/s, episode=6500, return=-20.5
# Iteration 130: 100%|█| 50/50 [00:34<00:00,  1.44it/s, episode=6550, return=-20.6
# Iteration 131: 100%|█| 50/50 [00:34<00:00,  1.47it/s, episode=6600, return=-20.4
# Iteration 132: 100%|█| 50/50 [00:35<00:00,  1.39it/s, episode=6650, return=-20.3
# Iteration 133: 100%|█| 50/50 [00:34<00:00,  1.44it/s, episode=6700, return=-20.7
# Iteration 134: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=6750, return=-20.5
# Iteration 135: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=6800, return=-20.3
# Iteration 136: 100%|█| 50/50 [00:34<00:00,  1.44it/s, episode=6850, return=-20.7
# Iteration 137: 100%|█| 50/50 [00:34<00:00,  1.43it/s, episode=6900, return=-20.3
# Iteration 138: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=6950, return=-20.7
# Iteration 139: 100%|█| 50/50 [00:34<00:00,  1.44it/s, episode=7000, return=-20.2
# Iteration 140: 100%|█| 50/50 [00:34<00:00,  1.44it/s, episode=7050, return=-20.6
# Iteration 141: 100%|█| 50/50 [00:34<00:00,  1.46it/s, episode=7100, return=-20.6
# Iteration 142: 100%|█| 50/50 [00:34<00:00,  1.45it/s, episode=7150, return=-20.6
# Iteration 143: 100%|█| 50/50 [00:34<00:00,  1.44it/s, episode=7200, return=-20.8
# Iteration 144: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=7250, return=-20.8
# Iteration 145: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=7300, return=-20.3
# Iteration 146: 100%|█| 50/50 [00:34<00:00,  1.43it/s, episode=7350, return=-20.7
# Iteration 147: 100%|█| 50/50 [00:34<00:00,  1.46it/s, episode=7400, return=-20.5
# Iteration 148: 100%|█| 50/50 [00:35<00:00,  1.43it/s, episode=7450, return=-20.3
# Iteration 149: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=7500, return=-20.6
# Iteration 150: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=7550, return=-20.9
# Iteration 151: 100%|█| 50/50 [00:34<00:00,  1.46it/s, episode=7600, return=-20.8
# Iteration 152: 100%|█| 50/50 [00:35<00:00,  1.43it/s, episode=7650, return=-20.6
# Iteration 153: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=7700, return=-20.5
# Iteration 154: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=7750, return=-20.5
# Iteration 155: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=7800, return=-20.7
# Iteration 156: 100%|█| 50/50 [00:34<00:00,  1.44it/s, episode=7850, return=-20.7
# Iteration 157: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=7900, return=-20.9
# Iteration 158: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=7950, return=-20.4
# Iteration 159: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=8000, return=-20.8
# Iteration 160: 100%|█| 50/50 [00:34<00:00,  1.44it/s, episode=8050, return=-21.0
# Iteration 161: 100%|█| 50/50 [00:34<00:00,  1.44it/s, episode=8100, return=-20.6
# Iteration 162: 100%|█| 50/50 [00:34<00:00,  1.45it/s, episode=8150, return=-20.8
# Iteration 163: 100%|█| 50/50 [00:36<00:00,  1.39it/s, episode=8200, return=-20.2
# Iteration 164: 100%|█| 50/50 [00:34<00:00,  1.44it/s, episode=8250, return=-20.6
# Iteration 165: 100%|█| 50/50 [00:34<00:00,  1.44it/s, episode=8300, return=-20.8
# Iteration 166: 100%|█| 50/50 [00:34<00:00,  1.44it/s, episode=8350, return=-20.9
# Iteration 167: 100%|█| 50/50 [00:34<00:00,  1.44it/s, episode=8400, return=-20.4
# Iteration 168: 100%|█| 50/50 [00:34<00:00,  1.45it/s, episode=8450, return=-20.4
# Iteration 169: 100%|█| 50/50 [00:35<00:00,  1.43it/s, episode=8500, return=-20.5
# Iteration 170: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=8550, return=-20.4
# Iteration 171: 100%|█| 50/50 [00:34<00:00,  1.45it/s, episode=8600, return=-20.7
# Iteration 172: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=8650, return=-20.7
# Iteration 173: 100%|█| 50/50 [00:34<00:00,  1.46it/s, episode=8700, return=-20.7
# Iteration 174: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=8750, return=-20.7
# Iteration 175: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=8800, return=-20.7
# Iteration 176: 100%|█| 50/50 [00:34<00:00,  1.46it/s, episode=8850, return=-20.6
# Iteration 177: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=8900, return=-20.5
# Iteration 178: 100%|█| 50/50 [00:34<00:00,  1.43it/s, episode=8950, return=-20.4
# Iteration 179: 100%|█| 50/50 [00:34<00:00,  1.43it/s, episode=9000, return=-20.7
# Iteration 180: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=9050, return=-20.7
# Iteration 181: 100%|█| 50/50 [00:34<00:00,  1.47it/s, episode=9100, return=-20.7
# Iteration 182: 100%|█| 50/50 [00:34<00:00,  1.45it/s, episode=9150, return=-20.1
# Iteration 183: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=9200, return=-20.7
# Iteration 184: 100%|█| 50/50 [00:34<00:00,  1.43it/s, episode=9250, return=-20.6
# Iteration 185: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=9300, return=-20.4
# Iteration 186: 100%|█| 50/50 [00:34<00:00,  1.43it/s, episode=9350, return=-20.7
# Iteration 187: 100%|█| 50/50 [00:34<00:00,  1.44it/s, episode=9400, return=-20.7
# Iteration 188: 100%|█| 50/50 [00:34<00:00,  1.45it/s, episode=9450, return=-20.7
# Iteration 189: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=9500, return=-20.3
# Iteration 190: 100%|█| 50/50 [00:33<00:00,  1.47it/s, episode=9550, return=-20.8
# Iteration 191: 100%|█| 50/50 [00:34<00:00,  1.46it/s, episode=9600, return=-21.0
# Iteration 192: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=9650, return=-20.7
# Iteration 193: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=9700, return=-20.8
# Iteration 194: 100%|█| 50/50 [00:34<00:00,  1.43it/s, episode=9750, return=-20.7
# Iteration 195: 100%|█| 50/50 [00:34<00:00,  1.45it/s, episode=9800, return=-20.8
# Iteration 196: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=9850, return=-20.6
# Iteration 197: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=9900, return=-20.6
# Iteration 198: 100%|█| 50/50 [00:34<00:00,  1.45it/s, episode=9950, return=-20.4
# Iteration 199: 100%|█| 50/50 [00:34<00:00,  1.43it/s, episode=10000, return=-20.
# Iteration 200: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=10050, return=-20.
# Iteration 201: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=10100, return=-20.
# Iteration 202: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=10150, return=-20.
# Iteration 203: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=10200, return=-20.
# Iteration 204: 100%|█| 50/50 [00:34<00:00,  1.45it/s, episode=10250, return=-20.
# Iteration 205: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=10300, return=-20.
# Iteration 206: 100%|█| 50/50 [00:34<00:00,  1.44it/s, episode=10350, return=-20.
# Iteration 207: 100%|█| 50/50 [00:34<00:00,  1.44it/s, episode=10400, return=-20.
# Iteration 208: 100%|█| 50/50 [00:34<00:00,  1.44it/s, episode=10450, return=-20.
# Iteration 209: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=10500, return=-20.
# Iteration 210: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=10550, return=-20.
# Iteration 211: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=10600, return=-20.
# Iteration 212: 100%|█| 50/50 [00:34<00:00,  1.44it/s, episode=10650, return=-20.
# Iteration 213: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=10700, return=-20.
# Iteration 214: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=10750, return=-20.
# Iteration 215: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=10800, return=-20.
# Iteration 216: 100%|█| 50/50 [00:35<00:00,  1.43it/s, episode=10850, return=-20.
# Iteration 217: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=10900, return=-20.
# Iteration 218: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=10950, return=-20.
# Iteration 219: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=11000, return=-20.
# Iteration 220: 100%|█| 50/50 [00:37<00:00,  1.35it/s, episode=11050, return=-20.
# Iteration 221: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=11100, return=-20.
# Iteration 222: 100%|█| 50/50 [00:35<00:00,  1.39it/s, episode=11150, return=-20.
# Iteration 223: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=11200, return=-20.
# Iteration 224: 100%|█| 50/50 [00:37<00:00,  1.33it/s, episode=11250, return=-20.
# Iteration 225: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=11300, return=-20.
# Iteration 226: 100%|█| 50/50 [00:34<00:00,  1.43it/s, episode=11350, return=-20.
# Iteration 227: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=11400, return=-20.
# Iteration 228: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=11450, return=-20.
# Iteration 229: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=11500, return=-20.
# Iteration 230: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=11550, return=-20.
# Iteration 231: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=11600, return=-20.
# Iteration 232: 100%|█| 50/50 [00:36<00:00,  1.39it/s, episode=11650, return=-20.
# Iteration 233: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=11700, return=-20.
# Iteration 234: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=11750, return=-20.
# Iteration 235: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=11800, return=-20.
# Iteration 236: 100%|█| 50/50 [00:36<00:00,  1.39it/s, episode=11850, return=-20.
# Iteration 237: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=11900, return=-20.
# Iteration 238: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=11950, return=-20.
# Iteration 239: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=12000, return=-20.
# Iteration 240: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=12050, return=-20.
# Iteration 241: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=12100, return=-20.
# Iteration 242: 100%|█| 50/50 [00:35<00:00,  1.39it/s, episode=12150, return=-20.
# Iteration 243: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=12200, return=-20.
# Iteration 244: 100%|█| 50/50 [00:36<00:00,  1.35it/s, episode=12250, return=-20.
# Iteration 245: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=12300, return=-20.
# Iteration 246: 100%|█| 50/50 [00:35<00:00,  1.39it/s, episode=12350, return=-20.
# Iteration 247: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=12400, return=-20.
# Iteration 248: 100%|█| 50/50 [00:34<00:00,  1.43it/s, episode=12450, return=-20.
# Iteration 249: 100%|█| 50/50 [00:35<00:00,  1.39it/s, episode=12500, return=-20.
# Iteration 250: 100%|█| 50/50 [00:35<00:00,  1.43it/s, episode=12550, return=-20.
# Iteration 251: 100%|█| 50/50 [00:36<00:00,  1.39it/s, episode=12600, return=-20.
# Iteration 252: 100%|█| 50/50 [00:34<00:00,  1.44it/s, episode=12650, return=-20.
# Iteration 253: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=12700, return=-20.
# Iteration 254: 100%|█| 50/50 [00:37<00:00,  1.35it/s, episode=12750, return=-20.
# Iteration 255: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=12800, return=-20.
# Iteration 256: 100%|█| 50/50 [00:35<00:00,  1.39it/s, episode=12850, return=-20.
# Iteration 257: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=12900, return=-20.
# Iteration 258: 100%|█| 50/50 [00:37<00:00,  1.35it/s, episode=12950, return=-21.
# Iteration 259: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=13000, return=-20.
# Iteration 260: 100%|█| 50/50 [00:37<00:00,  1.33it/s, episode=13050, return=-20.
# Iteration 261: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=13100, return=-20.
# Iteration 262: 100%|█| 50/50 [00:35<00:00,  1.39it/s, episode=13150, return=-20.
# Iteration 263: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=13200, return=-20.
# Iteration 264: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=13250, return=-20.
# Iteration 265: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=13300, return=-20.
# Iteration 266: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=13350, return=-20.
# Iteration 267: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=13400, return=-20.
# Iteration 268: 100%|█| 50/50 [00:35<00:00,  1.43it/s, episode=13450, return=-20.
# Iteration 269: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=13500, return=-20.
# Iteration 270: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=13550, return=-20.
# Iteration 271: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=13600, return=-20.
# Iteration 272: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=13650, return=-20.
# Iteration 273: 100%|█| 50/50 [00:36<00:00,  1.39it/s, episode=13700, return=-20.
# Iteration 274: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=13750, return=-20.
# Iteration 275: 100%|█| 50/50 [00:35<00:00,  1.43it/s, episode=13800, return=-20.
# Iteration 276: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=13850, return=-20.
# Iteration 277: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=13900, return=-20.
# Iteration 278: 100%|█| 50/50 [00:35<00:00,  1.39it/s, episode=13950, return=-20.
# Iteration 279: 100%|█| 50/50 [00:37<00:00,  1.35it/s, episode=14000, return=-20.
# Iteration 280: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=14050, return=-20.
# Iteration 281: 100%|█| 50/50 [00:36<00:00,  1.35it/s, episode=14100, return=-20.
# Iteration 282: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=14150, return=-20.
# Iteration 283: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=14200, return=-20.
# Iteration 284: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=14250, return=-20.
# Iteration 285: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=14300, return=-20.
# Iteration 286: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=14350, return=-20.
# Iteration 287: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=14400, return=-20.
# Iteration 288: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=14450, return=-20.
# Iteration 289: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=14500, return=-20.
# Iteration 290: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=14550, return=-20.
# Iteration 291: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=14600, return=-20.
# Iteration 292: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=14650, return=-20.
# Iteration 293: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=14700, return=-20.
# Iteration 294: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=14750, return=-19.
# Iteration 295: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=14800, return=-20.
# Iteration 296: 100%|█| 50/50 [00:35<00:00,  1.39it/s, episode=14850, return=-20.
# Iteration 297: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=14900, return=-20.
# Iteration 298: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=14950, return=-20.
# Iteration 299: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=15000, return=-21.
# Iteration 300: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=15050, return=-20.
# Iteration 301: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=15100, return=-20.
# Iteration 302: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=15150, return=-20.
# Iteration 303: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=15200, return=-20.
# Iteration 304: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=15250, return=-20.
# Iteration 305: 100%|█| 50/50 [00:37<00:00,  1.33it/s, episode=15300, return=-20.
# Iteration 306: 100%|█| 50/50 [00:36<00:00,  1.39it/s, episode=15350, return=-20.
# Iteration 307: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=15400, return=-20.
# Iteration 308: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=15450, return=-20.
# Iteration 309: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=15500, return=-20.
# Iteration 310: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=15550, return=-20.
# Iteration 311: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=15600, return=-21.
# Iteration 312: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=15650, return=-20.
# Iteration 313: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=15700, return=-20.
# Iteration 314: 100%|█| 50/50 [00:35<00:00,  1.39it/s, episode=15750, return=-20.
# Iteration 315: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=15800, return=-20.
# Iteration 316: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=15850, return=-20.
# Iteration 317: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=15900, return=-20.
# Iteration 318: 100%|█| 50/50 [00:36<00:00,  1.35it/s, episode=15950, return=-20.
# Iteration 319: 100%|█| 50/50 [00:36<00:00,  1.39it/s, episode=16000, return=-20.
# Iteration 320: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=16050, return=-20.
# Iteration 321: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=16100, return=-20.
# Iteration 322: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=16150, return=-20.
# Iteration 323: 100%|█| 50/50 [00:34<00:00,  1.45it/s, episode=16200, return=-21.
# Iteration 324: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=16250, return=-20.
# Iteration 325: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=16300, return=-20.
# Iteration 326: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=16350, return=-20.
# Iteration 327: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=16400, return=-20.
# Iteration 328: 100%|█| 50/50 [00:35<00:00,  1.39it/s, episode=16450, return=-20.
# Iteration 329: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=16500, return=-20.
# Iteration 330: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=16550, return=-20.
# Iteration 331: 100%|█| 50/50 [00:34<00:00,  1.43it/s, episode=16600, return=-20.
# Iteration 332: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=16650, return=-20.
# Iteration 333: 100%|█| 50/50 [00:35<00:00,  1.43it/s, episode=16700, return=-20.
# Iteration 334: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=16750, return=-20.
# Iteration 335: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=16800, return=-20.
# Iteration 336: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=16850, return=-20.
# Iteration 337: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=16900, return=-20.
# Iteration 338: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=16950, return=-20.
# Iteration 339: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=17000, return=-20.
# Iteration 340: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=17050, return=-20.
# Iteration 341: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=17100, return=-20.
# Iteration 342: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=17150, return=-20.
# Iteration 343: 100%|█| 50/50 [00:36<00:00,  1.39it/s, episode=17200, return=-20.
# Iteration 344: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=17250, return=-20.
# Iteration 345: 100%|█| 50/50 [00:36<00:00,  1.39it/s, episode=17300, return=-20.
# Iteration 346: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=17350, return=-20.
# Iteration 347: 100%|█| 50/50 [00:35<00:00,  1.39it/s, episode=17400, return=-20.
# Iteration 348: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=17450, return=-20.
# Iteration 349: 100%|█| 50/50 [00:36<00:00,  1.39it/s, episode=17500, return=-20.
# Iteration 350: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=17550, return=-20.
# Iteration 351: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=17600, return=-20.
# Iteration 352: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=17650, return=-20.
# Iteration 353: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=17700, return=-20.
# Iteration 354: 100%|█| 50/50 [00:37<00:00,  1.35it/s, episode=17750, return=-20.
# Iteration 355: 100%|█| 50/50 [00:34<00:00,  1.43it/s, episode=17800, return=-20.
# Iteration 356: 100%|█| 50/50 [00:35<00:00,  1.42it/s, episode=17850, return=-21.
# Iteration 357: 100%|█| 50/50 [00:35<00:00,  1.39it/s, episode=17900, return=-20.
# Iteration 358: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=17950, return=-20.
# Iteration 359: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=18000, return=-20.
# Iteration 360: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=18050, return=-20.
# Iteration 361: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=18100, return=-20.
# Iteration 362: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=18150, return=-20.
# Iteration 363: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=18200, return=-20.
# Iteration 364: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=18250, return=-20.
# Iteration 365: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=18300, return=-20.
# Iteration 366: 100%|█| 50/50 [00:35<00:00,  1.39it/s, episode=18350, return=-20.
# Iteration 367: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=18400, return=-20.
# Iteration 368: 100%|█| 50/50 [00:35<00:00,  1.39it/s, episode=18450, return=-20.
# Iteration 369: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=18500, return=-20.
# Iteration 370: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=18550, return=-20.
# Iteration 371: 100%|█| 50/50 [00:35<00:00,  1.39it/s, episode=18600, return=-20.
# Iteration 372: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=18650, return=-20.
# Iteration 373: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=18700, return=-20.
# Iteration 374: 100%|█| 50/50 [00:34<00:00,  1.43it/s, episode=18750, return=-20.
# Iteration 375: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=18800, return=-20.
# Iteration 376: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=18850, return=-20.
# Iteration 377: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=18900, return=-20.
# Iteration 378: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=18950, return=-20.
# Iteration 379: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=19000, return=-20.
# Iteration 380: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=19050, return=-20.
# Iteration 381: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=19100, return=-20.
# Iteration 382: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=19150, return=-20.
# Iteration 383: 100%|█| 50/50 [00:35<00:00,  1.39it/s, episode=19200, return=-20.
# Iteration 384: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=19250, return=-20.
# Iteration 385: 100%|█| 50/50 [00:36<00:00,  1.39it/s, episode=19300, return=-20.
# Iteration 386: 100%|█| 50/50 [00:34<00:00,  1.44it/s, episode=19350, return=-20.
# Iteration 387: 100%|█| 50/50 [00:36<00:00,  1.35it/s, episode=19400, return=-20.
# Iteration 388: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=19450, return=-20.
# Iteration 389: 100%|█| 50/50 [00:36<00:00,  1.39it/s, episode=19500, return=-20.
# Iteration 390: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=19550, return=-20.
# Iteration 391: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=19600, return=-20.
# Iteration 392: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=19650, return=-20.
# Iteration 393: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=19700, return=-20.
# Iteration 394: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=19750, return=-20.
# Iteration 395: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=19800, return=-20.
# Iteration 396: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=19850, return=-20.
# Iteration 397: 100%|█| 50/50 [00:37<00:00,  1.35it/s, episode=19900, return=-20.
# Iteration 398: 100%|█| 50/50 [00:37<00:00,  1.32it/s, episode=19950, return=-20.
# Iteration 399: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=20000, return=-20.
# Iteration 400: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=20050, return=-20.
# Iteration 401: 100%|█| 50/50 [00:39<00:00,  1.28it/s, episode=20100, return=-20.
# Iteration 402: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=20150, return=-20.
# Iteration 403: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=20200, return=-20.
# Iteration 404: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=20250, return=-20.
# Iteration 405: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=20300, return=-20.
# Iteration 406: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=20350, return=-20.
# Iteration 407: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=20400, return=-20.
# Iteration 408: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=20450, return=-20.
# Iteration 409: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=20500, return=-20.
# Iteration 410: 100%|█| 50/50 [00:37<00:00,  1.35it/s, episode=20550, return=-20.
# Iteration 411: 100%|█| 50/50 [00:37<00:00,  1.32it/s, episode=20600, return=-20.
# Iteration 412: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=20650, return=-20.
# Iteration 413: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=20700, return=-20.
# Iteration 414: 100%|█| 50/50 [00:37<00:00,  1.33it/s, episode=20750, return=-20.
# Iteration 415: 100%|█| 50/50 [00:37<00:00,  1.33it/s, episode=20800, return=-20.
# Iteration 416: 100%|█| 50/50 [00:37<00:00,  1.33it/s, episode=20850, return=-20.
# Iteration 417: 100%|█| 50/50 [00:37<00:00,  1.35it/s, episode=20900, return=-20.
# Iteration 418: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=20950, return=-20.
# Iteration 419: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=21000, return=-20.
# Iteration 420: 100%|█| 50/50 [00:36<00:00,  1.39it/s, episode=21050, return=-20.
# Iteration 421: 100%|█| 50/50 [00:38<00:00,  1.30it/s, episode=21100, return=-20.
# Iteration 422: 100%|█| 50/50 [00:37<00:00,  1.33it/s, episode=21150, return=-20.
# Iteration 423: 100%|█| 50/50 [00:37<00:00,  1.35it/s, episode=21200, return=-20.
# Iteration 424: 100%|█| 50/50 [00:37<00:00,  1.35it/s, episode=21250, return=-20.
# Iteration 425: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=21300, return=-20.
# Iteration 426: 100%|█| 50/50 [00:35<00:00,  1.39it/s, episode=21350, return=-20.
# Iteration 427: 100%|█| 50/50 [00:36<00:00,  1.39it/s, episode=21400, return=-20.
# Iteration 428: 100%|█| 50/50 [00:37<00:00,  1.35it/s, episode=21450, return=-20.
# Iteration 429: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=21500, return=-20.
# Iteration 430: 100%|█| 50/50 [00:37<00:00,  1.35it/s, episode=21550, return=-20.
# Iteration 431: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=21600, return=-20.
# Iteration 432: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=21650, return=-20.
# Iteration 433: 100%|█| 50/50 [00:38<00:00,  1.31it/s, episode=21700, return=-20.
# Iteration 434: 100%|█| 50/50 [00:38<00:00,  1.31it/s, episode=21750, return=-20.
# Iteration 435: 100%|█| 50/50 [00:37<00:00,  1.35it/s, episode=21800, return=-20.
# Iteration 436: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=21850, return=-20.
# Iteration 437: 100%|█| 50/50 [00:37<00:00,  1.32it/s, episode=21900, return=-20.
# Iteration 438: 100%|█| 50/50 [00:38<00:00,  1.30it/s, episode=21950, return=-20.
# Iteration 439: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=22000, return=-20.
# Iteration 440: 100%|█| 50/50 [00:35<00:00,  1.41it/s, episode=22050, return=-20.
# Iteration 441: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=22100, return=-20.
# Iteration 442: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=22150, return=-20.
# Iteration 443: 100%|█| 50/50 [00:38<00:00,  1.28it/s, episode=22200, return=-20.
# Iteration 444: 100%|█| 50/50 [00:37<00:00,  1.33it/s, episode=22250, return=-20.
# Iteration 445: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=22300, return=-20.
# Iteration 446: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=22350, return=-20.
# Iteration 447: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=22400, return=-20.
# Iteration 448: 100%|█| 50/50 [00:36<00:00,  1.35it/s, episode=22450, return=-20.
# Iteration 449: 100%|█| 50/50 [00:38<00:00,  1.31it/s, episode=22500, return=-20.
# Iteration 450: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=22550, return=-20.
# Iteration 451: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=22600, return=-20.
# Iteration 452: 100%|█| 50/50 [00:37<00:00,  1.33it/s, episode=22650, return=-20.
# Iteration 453: 100%|█| 50/50 [00:37<00:00,  1.35it/s, episode=22700, return=-20.
# Iteration 454: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=22750, return=-20.
# Iteration 455: 100%|█| 50/50 [00:38<00:00,  1.31it/s, episode=22800, return=-20.
# Iteration 456: 100%|█| 50/50 [00:37<00:00,  1.32it/s, episode=22850, return=-20.
# Iteration 457: 100%|█| 50/50 [00:36<00:00,  1.35it/s, episode=22900, return=-20.
# Iteration 458: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=22950, return=-20.
# Iteration 459: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=23000, return=-20.
# Iteration 460: 100%|█| 50/50 [00:37<00:00,  1.35it/s, episode=23050, return=-21.
# Iteration 461: 100%|█| 50/50 [00:38<00:00,  1.31it/s, episode=23100, return=-20.
# Iteration 462: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=23150, return=-20.
# Iteration 463: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=23200, return=-20.
# Iteration 464: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=23250, return=-20.
# Iteration 465: 100%|█| 50/50 [00:36<00:00,  1.35it/s, episode=23300, return=-20.
# Iteration 466: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=23350, return=-20.
# Iteration 467: 100%|█| 50/50 [00:37<00:00,  1.33it/s, episode=23400, return=-20.
# Iteration 468: 100%|█| 50/50 [00:37<00:00,  1.33it/s, episode=23450, return=-20.
# Iteration 469: 100%|█| 50/50 [00:37<00:00,  1.35it/s, episode=23500, return=-20.
# Iteration 470: 100%|█| 50/50 [00:37<00:00,  1.32it/s, episode=23550, return=-20.
# Iteration 471: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=23600, return=-20.
# Iteration 472: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=23650, return=-20.
# Iteration 473: 100%|█| 50/50 [00:38<00:00,  1.31it/s, episode=23700, return=-20.
# Iteration 474: 100%|█| 50/50 [00:37<00:00,  1.32it/s, episode=23750, return=-20.
# Iteration 475: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=23800, return=-20.
# Iteration 476: 100%|█| 50/50 [00:37<00:00,  1.33it/s, episode=23850, return=-20.
# Iteration 477: 100%|█| 50/50 [00:37<00:00,  1.35it/s, episode=23900, return=-20.
# Iteration 478: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=23950, return=-21.
# Iteration 479: 100%|█| 50/50 [00:37<00:00,  1.35it/s, episode=24000, return=-20.
# Iteration 480: 100%|█| 50/50 [00:37<00:00,  1.33it/s, episode=24050, return=-20.
# Iteration 481: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=24100, return=-20.
# Iteration 482: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=24150, return=-20.
# Iteration 483: 100%|█| 50/50 [00:36<00:00,  1.35it/s, episode=24200, return=-20.
# Iteration 484: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=24250, return=-20.
# Iteration 485: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=24300, return=-20.
# Iteration 486: 100%|█| 50/50 [00:37<00:00,  1.32it/s, episode=24350, return=-20.
# Iteration 487: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=24400, return=-20.
# Iteration 488: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=24450, return=-20.
# Iteration 489: 100%|█| 50/50 [00:36<00:00,  1.35it/s, episode=24500, return=-20.
# Iteration 490: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=24550, return=-20.
# Iteration 491: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=24600, return=-20.
# Iteration 492: 100%|█| 50/50 [00:38<00:00,  1.31it/s, episode=24650, return=-21.
# Iteration 493: 100%|█| 50/50 [00:37<00:00,  1.35it/s, episode=24700, return=-20.
# Iteration 494: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=24750, return=-20.
# Iteration 495: 100%|█| 50/50 [00:37<00:00,  1.33it/s, episode=24800, return=-20.
# Iteration 496: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=24850, return=-20.
# Iteration 497: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=24900, return=-20.
# Iteration 498: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=24950, return=-20.
# Iteration 499: 100%|█| 50/50 [00:38<00:00,  1.31it/s, episode=25000, return=-20.
# Iteration 500: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=25050, return=-20.
# Iteration 501: 100%|█| 50/50 [00:38<00:00,  1.31it/s, episode=25100, return=-20.
# Iteration 502: 100%|█| 50/50 [00:37<00:00,  1.35it/s, episode=25150, return=-20.
# Iteration 503: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=25200, return=-20.
# Iteration 504: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=25250, return=-20.
# Iteration 505: 100%|█| 50/50 [00:37<00:00,  1.33it/s, episode=25300, return=-20.
# Iteration 506: 100%|█| 50/50 [00:36<00:00,  1.35it/s, episode=25350, return=-20.
# Iteration 507: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=25400, return=-21.
# Iteration 508: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=25450, return=-20.
# Iteration 509: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=25500, return=-20.
# Iteration 510: 100%|█| 50/50 [00:36<00:00,  1.39it/s, episode=25550, return=-20.
# Iteration 511: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=25600, return=-20.
# Iteration 512: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=25650, return=-20.
# Iteration 513: 100%|█| 50/50 [00:37<00:00,  1.33it/s, episode=25700, return=-20.
# Iteration 514: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=25750, return=-20.
# Iteration 515: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=25800, return=-20.
# Iteration 516: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=25850, return=-20.
# Iteration 517: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=25900, return=-20.
# Iteration 518: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=25950, return=-20.
# Iteration 519: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=26000, return=-20.
# Iteration 520: 100%|█| 50/50 [00:36<00:00,  1.39it/s, episode=26050, return=-21.
# Iteration 521: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=26100, return=-20.
# Iteration 522: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=26150, return=-20.
# Iteration 523: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=26200, return=-20.
# Iteration 524: 100%|█| 50/50 [00:37<00:00,  1.33it/s, episode=26250, return=-20.
# Iteration 525: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=26300, return=-20.
# Iteration 526: 100%|█| 50/50 [00:37<00:00,  1.33it/s, episode=26350, return=-20.
# Iteration 527: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=26400, return=-20.
# Iteration 528: 100%|█| 50/50 [00:37<00:00,  1.32it/s, episode=26450, return=-20.
# Iteration 529: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=26500, return=-20.
# Iteration 530: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=26550, return=-20.
# Iteration 531: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=26600, return=-20.
# Iteration 532: 100%|█| 50/50 [00:37<00:00,  1.35it/s, episode=26650, return=-20.
# Iteration 533: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=26700, return=-20.
# Iteration 534: 100%|█| 50/50 [00:36<00:00,  1.35it/s, episode=26750, return=-20.
# Iteration 535: 100%|█| 50/50 [00:37<00:00,  1.32it/s, episode=26800, return=-20.
# Iteration 536: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=26850, return=-20.
# Iteration 537: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=26900, return=-20.
# Iteration 538: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=26950, return=-20.
# Iteration 539: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=27000, return=-20.
# Iteration 540: 100%|█| 50/50 [00:37<00:00,  1.35it/s, episode=27050, return=-20.
# Iteration 541: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=27100, return=-20.
# Iteration 542: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=27150, return=-20.
# Iteration 543: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=27200, return=-20.
# Iteration 544: 100%|█| 50/50 [00:38<00:00,  1.31it/s, episode=27250, return=-20.
# Iteration 545: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=27300, return=-20.
# Iteration 546: 100%|█| 50/50 [00:37<00:00,  1.35it/s, episode=27350, return=-20.
# Iteration 547: 100%|█| 50/50 [00:38<00:00,  1.29it/s, episode=27400, return=-20.
# Iteration 548: 100%|█| 50/50 [00:35<00:00,  1.40it/s, episode=27450, return=-20.
# Iteration 549: 100%|█| 50/50 [00:39<00:00,  1.27it/s, episode=27500, return=-20.
# Iteration 550: 100%|█| 50/50 [00:37<00:00,  1.32it/s, episode=27550, return=-20.
# Iteration 551: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=27600, return=-20.
# Iteration 552: 100%|█| 50/50 [00:37<00:00,  1.33it/s, episode=27650, return=-20.
# Iteration 553: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=27700, return=-20.
# Iteration 554: 100%|█| 50/50 [00:37<00:00,  1.32it/s, episode=27750, return=-20.
# Iteration 555: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=27800, return=-20.
# Iteration 556: 100%|█| 50/50 [00:37<00:00,  1.33it/s, episode=27850, return=-20.
# Iteration 557: 100%|█| 50/50 [00:37<00:00,  1.35it/s, episode=27900, return=-20.
# Iteration 558: 100%|█| 50/50 [00:38<00:00,  1.31it/s, episode=27950, return=-20.
# Iteration 559: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=28000, return=-20.
# Iteration 560: 100%|█| 50/50 [00:37<00:00,  1.32it/s, episode=28050, return=-20.
# Iteration 561: 100%|█| 50/50 [00:37<00:00,  1.33it/s, episode=28100, return=-20.
# Iteration 562: 100%|█| 50/50 [00:37<00:00,  1.32it/s, episode=28150, return=-20.
# Iteration 563: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=28200, return=-20.
# Iteration 564: 100%|█| 50/50 [00:37<00:00,  1.33it/s, episode=28250, return=-20.
# Iteration 565: 100%|█| 50/50 [00:36<00:00,  1.35it/s, episode=28300, return=-20.
# Iteration 566: 100%|█| 50/50 [00:38<00:00,  1.31it/s, episode=28350, return=-20.
# Iteration 567: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=28400, return=-20.
# Iteration 568: 100%|█| 50/50 [00:36<00:00,  1.35it/s, episode=28450, return=-20.
# Iteration 569: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=28500, return=-20.
# Iteration 570: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=28550, return=-20.
# Iteration 571: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=28600, return=-20.
# Iteration 572: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=28650, return=-20.
# Iteration 573: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=28700, return=-20.
# Iteration 574: 100%|█| 50/50 [00:37<00:00,  1.33it/s, episode=28750, return=-20.
# Iteration 575: 100%|█| 50/50 [00:37<00:00,  1.32it/s, episode=28800, return=-20.
# Iteration 576: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=28850, return=-20.
# Iteration 577: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=28900, return=-20.
# Iteration 578: 100%|█| 50/50 [00:37<00:00,  1.32it/s, episode=28950, return=-20.
# Iteration 579: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=29000, return=-20.
# Iteration 580: 100%|█| 50/50 [00:38<00:00,  1.31it/s, episode=29050, return=-20.
# Iteration 581: 100%|█| 50/50 [00:36<00:00,  1.36it/s, episode=29100, return=-20.
# Iteration 582: 100%|█| 50/50 [00:36<00:00,  1.38it/s, episode=29150, return=-20.
# Iteration 583: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=29200, return=-20.
# Iteration 584: 100%|█| 50/50 [00:36<00:00,  1.37it/s, episode=29250, return=-20.
# Iteration 585: 100%|█| 50/50 [00:37<00:00,  1.34it/s, episode=29300, return=-20.
# ...
# Iteration 2803: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=140200, return=-2
# Iteration 2804: 100%|█| 50/50 [00:38<00:00,  1.30it/s, episode=140250, return=-2
# Iteration 2805: 100%|█| 50/50 [00:39<00:00,  1.27it/s, episode=140300, return=-2
# Iteration 2806: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=140350, return=-2
# Iteration 2807: 100%|█| 50/50 [00:40<00:00,  1.23it/s, episode=140400, return=-2
# Iteration 2808: 100%|█| 50/50 [00:40<00:00,  1.22it/s, episode=140450, return=-2
# Iteration 2809: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=140500, return=-1
# Iteration 2810: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=140550, return=-2
# Iteration 2811: 100%|█| 50/50 [00:40<00:00,  1.25it/s, episode=140600, return=-2
# Iteration 2812: 100%|█| 50/50 [00:38<00:00,  1.31it/s, episode=140650, return=-2
# Iteration 2813: 100%|█| 50/50 [00:39<00:00,  1.27it/s, episode=140700, return=-2
# Iteration 2814: 100%|█| 50/50 [00:38<00:00,  1.28it/s, episode=140750, return=-2
# Iteration 2815: 100%|█| 50/50 [00:41<00:00,  1.21it/s, episode=140800, return=-2
# Iteration 2816: 100%|█| 50/50 [00:39<00:00,  1.27it/s, episode=140850, return=-2
# Iteration 2817: 100%|█| 50/50 [00:40<00:00,  1.25it/s, episode=140900, return=-2
# Iteration 2818: 100%|█| 50/50 [00:40<00:00,  1.24it/s, episode=140950, return=-2
# Iteration 2819: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=141000, return=-2
# Iteration 2820: 100%|█| 50/50 [00:39<00:00,  1.25it/s, episode=141050, return=-2
# Iteration 2821: 100%|█| 50/50 [00:39<00:00,  1.27it/s, episode=141100, return=-2
# Iteration 2822: 100%|█| 50/50 [00:39<00:00,  1.28it/s, episode=141150, return=-2
# Iteration 2823: 100%|█| 50/50 [00:40<00:00,  1.23it/s, episode=141200, return=-2
# Iteration 2824: 100%|█| 50/50 [00:39<00:00,  1.25it/s, episode=141250, return=-2
# Iteration 2825: 100%|█| 50/50 [00:39<00:00,  1.25it/s, episode=141300, return=-2
# Iteration 2826: 100%|█| 50/50 [00:39<00:00,  1.28it/s, episode=141350, return=-2
# Iteration 2827: 100%|█| 50/50 [00:40<00:00,  1.24it/s, episode=141400, return=-2
# Iteration 2828: 100%|█| 50/50 [00:38<00:00,  1.28it/s, episode=141450, return=-2
# Iteration 2829: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=141500, return=-2
# Iteration 2830: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=141550, return=-2
# Iteration 2831: 100%|█| 50/50 [00:39<00:00,  1.27it/s, episode=141600, return=-2
# Iteration 2832: 100%|█| 50/50 [00:40<00:00,  1.25it/s, episode=141650, return=-2
# Iteration 2833: 100%|█| 50/50 [00:38<00:00,  1.29it/s, episode=141700, return=-2
# Iteration 2834: 100%|█| 50/50 [00:40<00:00,  1.25it/s, episode=141750, return=-2
# Iteration 2835: 100%|█| 50/50 [00:38<00:00,  1.29it/s, episode=141800, return=-2
# Iteration 2836: 100%|█| 50/50 [00:39<00:00,  1.25it/s, episode=141850, return=-2
# Iteration 2837: 100%|█| 50/50 [00:38<00:00,  1.30it/s, episode=141900, return=-2
# Iteration 2838: 100%|█| 50/50 [00:40<00:00,  1.24it/s, episode=141950, return=-2
# Iteration 2839: 100%|█| 50/50 [00:39<00:00,  1.28it/s, episode=142000, return=-2
# Iteration 2840: 100%|█| 50/50 [00:40<00:00,  1.25it/s, episode=142050, return=-2
# Iteration 2841: 100%|█| 50/50 [00:39<00:00,  1.28it/s, episode=142100, return=-2
# Iteration 2842: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=142150, return=-2
# Iteration 2843: 100%|█| 50/50 [00:39<00:00,  1.27it/s, episode=142200, return=-2
# Iteration 2844: 100%|█| 50/50 [00:38<00:00,  1.29it/s, episode=142250, return=-2
# Iteration 2845: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=142300, return=-2
# Iteration 2846: 100%|█| 50/50 [00:38<00:00,  1.30it/s, episode=142350, return=-2
# Iteration 2847: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=142400, return=-2
# Iteration 2848: 100%|█| 50/50 [00:39<00:00,  1.27it/s, episode=142450, return=-2
# Iteration 2849: 100%|█| 50/50 [00:40<00:00,  1.23it/s, episode=142500, return=-2
# Iteration 2850: 100%|█| 50/50 [00:38<00:00,  1.29it/s, episode=142550, return=-2
# Iteration 2851: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=142600, return=-2
# Iteration 2852: 100%|█| 50/50 [00:40<00:00,  1.24it/s, episode=142650, return=-2
# Iteration 2853: 100%|█| 50/50 [00:40<00:00,  1.25it/s, episode=142700, return=-2
# Iteration 2854: 100%|█| 50/50 [00:38<00:00,  1.28it/s, episode=142750, return=-2
# Iteration 2855: 100%|█| 50/50 [00:40<00:00,  1.24it/s, episode=142800, return=-2
# Iteration 2856: 100%|█| 50/50 [00:41<00:00,  1.20it/s, episode=142850, return=-2
# Iteration 2857: 100%|█| 50/50 [00:41<00:00,  1.21it/s, episode=142900, return=-2
# Iteration 2858: 100%|█| 50/50 [00:39<00:00,  1.25it/s, episode=142950, return=-2
# Iteration 2859: 100%|█| 50/50 [00:40<00:00,  1.24it/s, episode=143000, return=-2
# Iteration 2860: 100%|█| 50/50 [00:39<00:00,  1.25it/s, episode=143050, return=-2
# Iteration 2861: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=143100, return=-2
# Iteration 2862: 100%|█| 50/50 [00:39<00:00,  1.25it/s, episode=143150, return=-2
# Iteration 2863: 100%|█| 50/50 [00:39<00:00,  1.25it/s, episode=143200, return=-2
# Iteration 2864: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=143250, return=-2
# Iteration 2865: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=143300, return=-2
# Iteration 2866: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=143350, return=-2
# Iteration 2867: 100%|█| 50/50 [00:41<00:00,  1.22it/s, episode=143400, return=-2
# Iteration 2868: 100%|█| 50/50 [00:39<00:00,  1.27it/s, episode=143450, return=-2
# Iteration 2869: 100%|█| 50/50 [00:40<00:00,  1.25it/s, episode=143500, return=-2
# Iteration 2870: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=143550, return=-2
# Iteration 2871: 100%|█| 50/50 [00:40<00:00,  1.23it/s, episode=143600, return=-2
# Iteration 2872: 100%|█| 50/50 [00:38<00:00,  1.29it/s, episode=143650, return=-2
# Iteration 2873: 100%|█| 50/50 [00:39<00:00,  1.25it/s, episode=143700, return=-2
# Iteration 2874: 100%|█| 50/50 [00:39<00:00,  1.28it/s, episode=143750, return=-2
# Iteration 2875: 100%|█| 50/50 [00:39<00:00,  1.25it/s, episode=143800, return=-2
# Iteration 2876: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=143850, return=-2
# Iteration 2877: 100%|█| 50/50 [00:40<00:00,  1.22it/s, episode=143900, return=-2
# Iteration 2878: 100%|█| 50/50 [00:40<00:00,  1.25it/s, episode=143950, return=-2
# Iteration 2879: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=144000, return=-2
# Iteration 2880: 100%|█| 50/50 [00:38<00:00,  1.30it/s, episode=144050, return=-2
# Iteration 2881: 100%|█| 50/50 [00:40<00:00,  1.24it/s, episode=144100, return=-2
# Iteration 2882: 100%|█| 50/50 [00:39<00:00,  1.28it/s, episode=144150, return=-2
# Iteration 2883: 100%|█| 50/50 [00:40<00:00,  1.24it/s, episode=144200, return=-2
# Iteration 2884: 100%|█| 50/50 [00:40<00:00,  1.23it/s, episode=144250, return=-2
# Iteration 2885: 100%|█| 50/50 [00:41<00:00,  1.21it/s, episode=144300, return=-2
# Iteration 2886: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=144350, return=-2
# Iteration 2887: 100%|█| 50/50 [00:40<00:00,  1.24it/s, episode=144400, return=-2
# Iteration 2888: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=144450, return=-2
# Iteration 2889: 100%|█| 50/50 [00:39<00:00,  1.25it/s, episode=144500, return=-2
# Iteration 2890: 100%|█| 50/50 [00:40<00:00,  1.24it/s, episode=144550, return=-2
# Iteration 2891: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=144600, return=-2
# Iteration 2892: 100%|█| 50/50 [00:38<00:00,  1.30it/s, episode=144650, return=-2
# Iteration 2893: 100%|█| 50/50 [00:40<00:00,  1.25it/s, episode=144700, return=-2
# Iteration 2894: 100%|█| 50/50 [00:39<00:00,  1.27it/s, episode=144750, return=-2
# Iteration 2895: 100%|█| 50/50 [00:40<00:00,  1.23it/s, episode=144800, return=-2
# Iteration 2896: 100%|█| 50/50 [00:38<00:00,  1.30it/s, episode=144850, return=-2
# Iteration 2897: 100%|█| 50/50 [00:39<00:00,  1.27it/s, episode=144900, return=-2
# Iteration 2898: 100%|█| 50/50 [00:41<00:00,  1.22it/s, episode=144950, return=-2
# Iteration 2899: 100%|█| 50/50 [00:40<00:00,  1.24it/s, episode=145000, return=-2
# Iteration 2900: 100%|█| 50/50 [00:39<00:00,  1.28it/s, episode=145050, return=-2
# Iteration 2901: 100%|█| 50/50 [00:39<00:00,  1.25it/s, episode=145100, return=-2
# Iteration 2902: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=145150, return=-2
# Iteration 2903: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=145200, return=-2
# Iteration 2904: 100%|█| 50/50 [00:39<00:00,  1.25it/s, episode=145250, return=-2
# Iteration 2905: 100%|█| 50/50 [00:38<00:00,  1.29it/s, episode=145300, return=-2
# Iteration 2906: 100%|█| 50/50 [00:39<00:00,  1.25it/s, episode=145350, return=-2
# Iteration 2907: 100%|█| 50/50 [00:38<00:00,  1.28it/s, episode=145400, return=-2
# Iteration 2908: 100%|█| 50/50 [00:39<00:00,  1.28it/s, episode=145450, return=-2
# Iteration 2909: 100%|█| 50/50 [00:38<00:00,  1.29it/s, episode=145500, return=-2
# Iteration 2910: 100%|█| 50/50 [00:40<00:00,  1.24it/s, episode=145550, return=-2
# Iteration 2911: 100%|█| 50/50 [00:40<00:00,  1.24it/s, episode=145600, return=-2
# Iteration 2912: 100%|█| 50/50 [00:38<00:00,  1.29it/s, episode=145650, return=-2
# Iteration 2913: 100%|█| 50/50 [00:39<00:00,  1.27it/s, episode=145700, return=-2
# Iteration 2914: 100%|█| 50/50 [00:40<00:00,  1.25it/s, episode=145750, return=-2
# Iteration 2915: 100%|█| 50/50 [00:39<00:00,  1.28it/s, episode=145800, return=-2
# Iteration 2916: 100%|█| 50/50 [00:40<00:00,  1.24it/s, episode=145850, return=-2
# Iteration 2917: 100%|█| 50/50 [00:38<00:00,  1.31it/s, episode=145900, return=-2
# Iteration 2918: 100%|█| 50/50 [00:39<00:00,  1.28it/s, episode=145950, return=-2
# Iteration 2919: 100%|█| 50/50 [00:39<00:00,  1.25it/s, episode=146000, return=-2
# Iteration 2920: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=146050, return=-2
# Iteration 2921: 100%|█| 50/50 [00:39<00:00,  1.25it/s, episode=146100, return=-2
# Iteration 2922: 100%|█| 50/50 [00:38<00:00,  1.28it/s, episode=146150, return=-1
# Iteration 2923: 100%|█| 50/50 [00:40<00:00,  1.24it/s, episode=146200, return=-2
# Iteration 2924: 100%|█| 50/50 [00:39<00:00,  1.25it/s, episode=146250, return=-2
# Iteration 2925: 100%|█| 50/50 [00:40<00:00,  1.25it/s, episode=146300, return=-2
# Iteration 2926: 100%|█| 50/50 [00:38<00:00,  1.29it/s, episode=146350, return=-2
# Iteration 2927: 100%|█| 50/50 [00:40<00:00,  1.25it/s, episode=146400, return=-2
# Iteration 2928: 100%|█| 50/50 [00:39<00:00,  1.28it/s, episode=146450, return=-2
# Iteration 2929: 100%|█| 50/50 [00:40<00:00,  1.23it/s, episode=146500, return=-2
# Iteration 2930: 100%|█| 50/50 [00:38<00:00,  1.28it/s, episode=146550, return=-2
# Iteration 2931: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=146600, return=-2
# Iteration 2932: 100%|█| 50/50 [00:40<00:00,  1.24it/s, episode=146650, return=-2
# Iteration 2933: 100%|█| 50/50 [00:39<00:00,  1.28it/s, episode=146700, return=-2
# Iteration 2934: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=146750, return=-2
# Iteration 2935: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=146800, return=-2
# Iteration 2936: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=146850, return=-2
# Iteration 2937: 100%|█| 50/50 [00:39<00:00,  1.25it/s, episode=146900, return=-2
# Iteration 2938: 100%|█| 50/50 [00:39<00:00,  1.27it/s, episode=146950, return=-2
# Iteration 2939: 100%|█| 50/50 [00:39<00:00,  1.28it/s, episode=147000, return=-2
# Iteration 2940: 100%|█| 50/50 [00:38<00:00,  1.29it/s, episode=147050, return=-2
# Iteration 2941: 100%|█| 50/50 [00:40<00:00,  1.24it/s, episode=147100, return=-2
# Iteration 2942: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=147150, return=-2
# Iteration 2943: 100%|█| 50/50 [00:40<00:00,  1.25it/s, episode=147200, return=-2
# Iteration 2944: 100%|█| 50/50 [00:40<00:00,  1.24it/s, episode=147250, return=-2
# Iteration 2945: 100%|█| 50/50 [00:39<00:00,  1.25it/s, episode=147300, return=-2
# Iteration 2946: 100%|█| 50/50 [00:38<00:00,  1.29it/s, episode=147350, return=-2
# Iteration 2947: 100%|█| 50/50 [00:39<00:00,  1.27it/s, episode=147400, return=-2
# Iteration 2948: 100%|█| 50/50 [00:40<00:00,  1.24it/s, episode=147450, return=-2
# Iteration 2949: 100%|█| 50/50 [00:40<00:00,  1.25it/s, episode=147500, return=-2
# Iteration 2950: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=147550, return=-2
# Iteration 2951: 100%|█| 50/50 [00:39<00:00,  1.25it/s, episode=147600, return=-2
# Iteration 2952: 100%|█| 50/50 [00:39<00:00,  1.27it/s, episode=147650, return=-2
# Iteration 2953: 100%|█| 50/50 [00:40<00:00,  1.24it/s, episode=147700, return=-2
# Iteration 2954: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=147750, return=-2
# Iteration 2955: 100%|█| 50/50 [00:39<00:00,  1.27it/s, episode=147800, return=-2
# Iteration 2956: 100%|█| 50/50 [00:40<00:00,  1.24it/s, episode=147850, return=-2
# Iteration 2957: 100%|█| 50/50 [00:40<00:00,  1.24it/s, episode=147900, return=-2
# Iteration 2958: 100%|█| 50/50 [00:40<00:00,  1.24it/s, episode=147950, return=-2
# Iteration 2959: 100%|█| 50/50 [00:40<00:00,  1.24it/s, episode=148000, return=-2
# Iteration 2960: 100%|█| 50/50 [00:40<00:00,  1.25it/s, episode=148050, return=-2
# Iteration 2961: 100%|█| 50/50 [00:38<00:00,  1.30it/s, episode=148100, return=-2
# Iteration 2962: 100%|█| 50/50 [00:41<00:00,  1.21it/s, episode=148150, return=-2
# Iteration 2963: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=148200, return=-2
# Iteration 2964: 100%|█| 50/50 [00:39<00:00,  1.25it/s, episode=148250, return=-2
# Iteration 2965: 100%|█| 50/50 [00:39<00:00,  1.27it/s, episode=148300, return=-2
# Iteration 2966: 100%|█| 50/50 [00:40<00:00,  1.23it/s, episode=148350, return=-2
# Iteration 2967: 100%|█| 50/50 [00:38<00:00,  1.28it/s, episode=148400, return=-2
# Iteration 2968: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=148450, return=-2
# Iteration 2969: 100%|█| 50/50 [00:38<00:00,  1.29it/s, episode=148500, return=-2
# Iteration 2970: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=148550, return=-2
# Iteration 2971: 100%|█| 50/50 [00:39<00:00,  1.27it/s, episode=148600, return=-2
# Iteration 2972: 100%|█| 50/50 [00:41<00:00,  1.20it/s, episode=148650, return=-2
# Iteration 2973: 100%|█| 50/50 [00:39<00:00,  1.28it/s, episode=148700, return=-2
# Iteration 2974: 100%|█| 50/50 [00:40<00:00,  1.23it/s, episode=148750, return=-2
# Iteration 2975: 100%|█| 50/50 [00:39<00:00,  1.27it/s, episode=148800, return=-2
# Iteration 2976: 100%|█| 50/50 [00:39<00:00,  1.27it/s, episode=148850, return=-2
# Iteration 2977: 100%|█| 50/50 [00:39<00:00,  1.27it/s, episode=148900, return=-2
# Iteration 2978: 100%|█| 50/50 [00:40<00:00,  1.25it/s, episode=148950, return=-2
# Iteration 2979: 100%|█| 50/50 [00:39<00:00,  1.27it/s, episode=149000, return=-2
# Iteration 2980: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=149050, return=-2
# Iteration 2981: 100%|█| 50/50 [00:40<00:00,  1.23it/s, episode=149100, return=-2
# Iteration 2982: 100%|█| 50/50 [00:40<00:00,  1.22it/s, episode=149150, return=-2
# Iteration 2983: 100%|█| 50/50 [00:40<00:00,  1.24it/s, episode=149200, return=-2
# Iteration 2984: 100%|█| 50/50 [00:39<00:00,  1.27it/s, episode=149250, return=-2
# Iteration 2985: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=149300, return=-2
# Iteration 2986: 100%|█| 50/50 [00:40<00:00,  1.24it/s, episode=149350, return=-2
# Iteration 2987: 100%|█| 50/50 [00:39<00:00,  1.27it/s, episode=149400, return=-2
# Iteration 2988: 100%|█| 50/50 [00:40<00:00,  1.22it/s, episode=149450, return=-2
# Iteration 2989: 100%|█| 50/50 [00:40<00:00,  1.23it/s, episode=149500, return=-2
# Iteration 2990: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=149550, return=-2
# Iteration 2991: 100%|█| 50/50 [00:38<00:00,  1.30it/s, episode=149600, return=-2
# Iteration 2992: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=149650, return=-2
# Iteration 2993: 100%|█| 50/50 [00:39<00:00,  1.25it/s, episode=149700, return=-2
# Iteration 2994: 100%|█| 50/50 [00:40<00:00,  1.25it/s, episode=149750, return=-2
# Iteration 2995: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=149800, return=-2
# Iteration 2996: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=149850, return=-2
# Iteration 2997: 100%|█| 50/50 [00:39<00:00,  1.27it/s, episode=149900, return=-2
# Iteration 2998: 100%|█| 50/50 [00:40<00:00,  1.23it/s, episode=149950, return=-2
# Iteration 2999: 100%|█| 50/50 [00:39<00:00,  1.26it/s, episode=150000, return=-2

# %%
episodes_list = list(range(len(return_list)))
plt.plot(episodes_list, return_list)
plt.xlabel('Episodes')
plt.ylabel('Returns')
plt.title('DQN on {}'.format(env_name))
plt.show()

mv_return = rl_utils.moving_average(return_list, 9)
plt.plot(episodes_list, mv_return)
plt.xlabel('Episodes')
plt.ylabel('Returns')
plt.title('DQN on {}'.format(env_name))
plt.show()

# %%
class ConvolutionalQnet(torch.nn.Module):
    ''' 加入卷积层的Q网络 '''
    def __init__(self, action_dim, in_channels=4):
        super(ConvolutionalQnet, self).__init__()
        self.conv1 = torch.nn.Conv2d(in_channels, 32, kernel_size=8, stride=4)
        self.conv2 = torch.nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = torch.nn.Conv2d(64, 64, kernel_size=3, stride=1)
        self.fc4 = torch.nn.Linear(7 * 7 * 64, 512)
        self.head = torch.nn.Linear(512, action_dim)

    def forward(self, x):
        x = x / 255
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = F.relu(self.fc4(x))
        return self.head(x)
