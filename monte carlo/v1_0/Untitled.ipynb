# %%
import gym
import torch
import matplotlib.pyplot as plt
import numpy as np
from ppo import PPO
from online_collect import online_collect
from rl_utils import moving_average

# %%
 actor_lr = 1e-4
critic_lr = 1e-4#面对复杂任务时，这个值最好降低，调到过3e-4，但是结果不是很理想
hidden_dim = 128
gamma = 0.99#平衡过程奖励和结果奖励
lmbda = 0.95
epochs = 3#原来是10
eps = 0.2 
minibatch_size=256#面对复杂任务时，这个值最好变大，详情可见ppo原文，update耗时很严重
device = torch.device("cuda") if torch.cuda.is_available() else torch.device(
    "cpu")
fixed_epi=10#改的是这个
env_name = 'Pong-ram-v0'
env = gym.make(env_name)
env.seed(0)
torch.manual_seed(0)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n
agent = PPO(state_dim, hidden_dim, action_dim, actor_lr, critic_lr, lmbda,
            epochs, eps, gamma, minibatch_size,device)
return_list = []

# %%
def compute_returns(rewards,gamma):
    returns=[]
    G=0
    for reward in reversed(rewards):
        G=reward+gamma*G
        returns.append(G)
    returns.reverse()
    return returns
import numpy as np

def online_collect(agent,env,fixed_epi,return_list,gamma):
    transition_dict = {'states': [], 'actions': [], 'next_states': [], 'rewards': [], 'dones': [],'returns':[]}
    total_epi=0
    episode_return = []
    state = env.reset()
    done = False
    while total_epi<fixed_epi:
        state=state.astype(np.float32)
        state/=255
        action = agent.take_action(state)
        next_state, reward, done, _ = env.step(action)
        transition_dict['states'].append(state)
        transition_dict['actions'].append(action)
        transition_dict['next_states'].append(next_state)
        transition_dict['rewards'].append(reward)
        transition_dict['dones'].append(done)
        state = next_state
        episode_return.append(reward)
        if done:
            total_epi+=1
            return_list.append(sum(episode_return))
            returns=compute_returns(episode_return,gamma)
            transition_dict['returns'].extend(returns)
            episode_return = []
            state = env.reset()
            done = False
    return transition_dict

# %%
for i in range(10000):
    transition_dict=online_collect(agent,env,fixed_epi,return_list,gamma)
    agent.offline_train(transition_dict)
    print(f"iteration{i}: average return of last 100 episodes is {np.mean(return_list[-10:])}")
# Out:
# iteration0: average return of last 100 episodes is -11.9
# iteration1: average return of last 100 episodes is -11.9
# iteration2: average return of last 100 episodes is -11.5
# iteration3: average return of last 100 episodes is -10.0
# iteration4: average return of last 100 episodes is -13.0
# iteration5: average return of last 100 episodes is -12.9
# iteration6: average return of last 100 episodes is -11.4
# iteration7: average return of last 100 episodes is -13.3
# iteration8: average return of last 100 episodes is -12.0
# iteration9: average return of last 100 episodes is -13.2
# iteration10: average return of last 100 episodes is -12.5
# iteration11: average return of last 100 episodes is -12.2
# iteration12: average return of last 100 episodes is -12.5
# iteration13: average return of last 100 episodes is -11.6
# iteration14: average return of last 100 episodes is -12.2
# iteration15: average return of last 100 episodes is -11.4
# iteration16: average return of last 100 episodes is -11.7
# iteration17: average return of last 100 episodes is -10.3
# iteration18: average return of last 100 episodes is -9.7
# iteration19: average return of last 100 episodes is -11.7
# iteration20: average return of last 100 episodes is -13.0
# iteration21: average return of last 100 episodes is -8.4
# iteration22: average return of last 100 episodes is -12.0
# iteration23: average return of last 100 episodes is -12.4
# iteration24: average return of last 100 episodes is -13.2
# iteration25: average return of last 100 episodes is -13.5
# iteration26: average return of last 100 episodes is -10.0
# iteration27: average return of last 100 episodes is -13.7
# iteration28: average return of last 100 episodes is -12.0
# iteration29: average return of last 100 episodes is -11.1
# iteration30: average return of last 100 episodes is -11.9
# iteration31: average return of last 100 episodes is -11.0
# iteration32: average return of last 100 episodes is -9.8
# iteration33: average return of last 100 episodes is -12.3
# iteration34: average return of last 100 episodes is -11.0
# iteration35: average return of last 100 episodes is -13.4
# iteration36: average return of last 100 episodes is -10.3
# iteration37: average return of last 100 episodes is -11.9
# iteration38: average return of last 100 episodes is -12.3
# iteration39: average return of last 100 episodes is -12.6
# iteration40: average return of last 100 episodes is -13.6
# iteration41: average return of last 100 episodes is -10.8
# iteration42: average return of last 100 episodes is -13.2
# iteration43: average return of last 100 episodes is -10.0
# iteration44: average return of last 100 episodes is -11.4
# iteration45: average return of last 100 episodes is -13.8
# iteration46: average return of last 100 episodes is -12.6
# iteration47: average return of last 100 episodes is -13.5
# iteration48: average return of last 100 episodes is -10.5
# iteration49: average return of last 100 episodes is -13.2
# iteration50: average return of last 100 episodes is -12.3
# iteration51: average return of last 100 episodes is -12.5
# iteration52: average return of last 100 episodes is -12.2
# iteration53: average return of last 100 episodes is -12.1
# iteration54: average return of last 100 episodes is -10.4
# iteration55: average return of last 100 episodes is -11.2
# iteration56: average return of last 100 episodes is -11.0
# iteration57: average return of last 100 episodes is -12.6
# iteration58: average return of last 100 episodes is -12.0
# iteration59: average return of last 100 episodes is -12.6
# iteration60: average return of last 100 episodes is -10.8
# iteration61: average return of last 100 episodes is -12.4
# iteration62: average return of last 100 episodes is -12.2
# iteration63: average return of last 100 episodes is -10.4
# iteration64: average return of last 100 episodes is -11.9
# iteration65: average return of last 100 episodes is -10.2
# iteration66: average return of last 100 episodes is -10.2
# iteration67: average return of last 100 episodes is -13.4
# iteration68: average return of last 100 episodes is -13.2
# iteration69: average return of last 100 episodes is -10.6
# iteration70: average return of last 100 episodes is -10.8
# iteration71: average return of last 100 episodes is -12.4
# iteration72: average return of last 100 episodes is -11.4
# iteration73: average return of last 100 episodes is -12.0
# iteration74: average return of last 100 episodes is -11.0
# iteration75: average return of last 100 episodes is -11.6
# iteration76: average return of last 100 episodes is -9.6
# iteration77: average return of last 100 episodes is -12.5
# iteration78: average return of last 100 episodes is -9.7
# iteration79: average return of last 100 episodes is -11.0
# iteration80: average return of last 100 episodes is -11.7
# iteration81: average return of last 100 episodes is -11.9
# iteration82: average return of last 100 episodes is -11.2
# iteration83: average return of last 100 episodes is -11.8
# iteration84: average return of last 100 episodes is -10.6
# iteration85: average return of last 100 episodes is -10.4
# iteration86: average return of last 100 episodes is -9.8
# iteration87: average return of last 100 episodes is -11.7
# iteration88: average return of last 100 episodes is -10.9
# iteration89: average return of last 100 episodes is -10.6
# iteration90: average return of last 100 episodes is -13.7
# iteration91: average return of last 100 episodes is -13.2
# iteration92: average return of last 100 episodes is -12.2
# iteration93: average return of last 100 episodes is -12.0
# iteration94: average return of last 100 episodes is -12.3
# iteration95: average return of last 100 episodes is -12.0
# iteration96: average return of last 100 episodes is -10.5
# iteration97: average return of last 100 episodes is -11.8
# iteration98: average return of last 100 episodes is -11.5
# iteration99: average return of last 100 episodes is -11.6
# iteration100: average return of last 100 episodes is -11.6
# iteration101: average return of last 100 episodes is -12.4
# iteration102: average return of last 100 episodes is -12.9
# iteration103: average return of last 100 episodes is -11.5
# iteration104: average return of last 100 episodes is -13.6
# iteration105: average return of last 100 episodes is -11.1
# iteration106: average return of last 100 episodes is -10.3
# iteration107: average return of last 100 episodes is -12.8
# iteration108: average return of last 100 episodes is -13.9
# iteration109: average return of last 100 episodes is -10.3
# iteration110: average return of last 100 episodes is -11.2
# iteration111: average return of last 100 episodes is -11.7
# iteration112: average return of last 100 episodes is -9.1
# iteration113: average return of last 100 episodes is -11.3
# iteration114: average return of last 100 episodes is -10.6
# iteration115: average return of last 100 episodes is -8.5
# iteration116: average return of last 100 episodes is -12.7
# iteration117: average return of last 100 episodes is -11.2
# iteration118: average return of last 100 episodes is -11.7
# iteration119: average return of last 100 episodes is -9.1
# iteration120: average return of last 100 episodes is -9.5
# iteration121: average return of last 100 episodes is -10.7
# iteration122: average return of last 100 episodes is -10.7
# iteration123: average return of last 100 episodes is -9.0
# iteration124: average return of last 100 episodes is -13.0
# iteration125: average return of last 100 episodes is -13.9
# iteration126: average return of last 100 episodes is -11.3
# iteration127: average return of last 100 episodes is -12.6
# iteration128: average return of last 100 episodes is -11.0
# iteration129: average return of last 100 episodes is -10.8
# iteration130: average return of last 100 episodes is -10.7
# iteration131: average return of last 100 episodes is -11.4
# iteration132: average return of last 100 episodes is -11.3
# iteration133: average return of last 100 episodes is -11.9
# iteration134: average return of last 100 episodes is -12.9
# iteration135: average return of last 100 episodes is -11.1
# iteration136: average return of last 100 episodes is -11.5
# iteration137: average return of last 100 episodes is -11.4
# iteration138: average return of last 100 episodes is -12.0
# iteration139: average return of last 100 episodes is -11.1
# iteration140: average return of last 100 episodes is -12.7
# iteration141: average return of last 100 episodes is -13.8
# iteration142: average return of last 100 episodes is -11.8
# iteration143: average return of last 100 episodes is -11.5
# iteration144: average return of last 100 episodes is -12.4
# iteration145: average return of last 100 episodes is -12.1
# iteration146: average return of last 100 episodes is -12.4
# iteration147: average return of last 100 episodes is -11.4
# iteration148: average return of last 100 episodes is -12.4
# iteration149: average return of last 100 episodes is -13.5
# iteration150: average return of last 100 episodes is -12.4
# iteration151: average return of last 100 episodes is -12.4
# iteration152: average return of last 100 episodes is -11.5
# iteration153: average return of last 100 episodes is -12.3
# iteration154: average return of last 100 episodes is -11.7
# iteration155: average return of last 100 episodes is -11.9
# iteration156: average return of last 100 episodes is -12.3
# iteration157: average return of last 100 episodes is -11.5
# iteration158: average return of last 100 episodes is -12.3
# iteration159: average return of last 100 episodes is -11.7
# iteration160: average return of last 100 episodes is -12.3
# iteration161: average return of last 100 episodes is -10.8
# iteration162: average return of last 100 episodes is -13.4
# iteration163: average return of last 100 episodes is -10.4
# iteration164: average return of last 100 episodes is -12.2
# iteration165: average return of last 100 episodes is -13.4
# iteration166: average return of last 100 episodes is -11.6
# iteration167: average return of last 100 episodes is -12.7
# iteration168: average return of last 100 episodes is -10.9
# iteration169: average return of last 100 episodes is -12.9
# iteration170: average return of last 100 episodes is -10.9
# iteration171: average return of last 100 episodes is -10.9
# iteration172: average return of last 100 episodes is -10.7
# iteration173: average return of last 100 episodes is -10.1
# iteration174: average return of last 100 episodes is -12.6
# iteration175: average return of last 100 episodes is -10.4
# iteration176: average return of last 100 episodes is -12.1
# iteration177: average return of last 100 episodes is -10.0
# iteration178: average return of last 100 episodes is -11.6
# iteration179: average return of last 100 episodes is -9.9
# iteration180: average return of last 100 episodes is -12.9
# iteration181: average return of last 100 episodes is -8.9
# iteration182: average return of last 100 episodes is -11.8
# iteration183: average return of last 100 episodes is -11.2
# iteration184: average return of last 100 episodes is -10.3
# iteration185: average return of last 100 episodes is -11.1
# iteration186: average return of last 100 episodes is -13.0
# iteration187: average return of last 100 episodes is -10.5
# iteration188: average return of last 100 episodes is -11.0
# iteration189: average return of last 100 episodes is -11.9
# iteration190: average return of last 100 episodes is -11.7
# iteration191: average return of last 100 episodes is -12.2
# iteration192: average return of last 100 episodes is -11.7
# iteration193: average return of last 100 episodes is -12.1
# iteration194: average return of last 100 episodes is -13.0
# iteration195: average return of last 100 episodes is -10.0
# iteration196: average return of last 100 episodes is -11.2
# iteration197: average return of last 100 episodes is -10.8
# iteration198: average return of last 100 episodes is -11.2
# iteration199: average return of last 100 episodes is -12.2
# iteration200: average return of last 100 episodes is -12.3
# iteration201: average return of last 100 episodes is -10.8
# iteration202: average return of last 100 episodes is -12.2
# iteration203: average return of last 100 episodes is -9.0
# iteration204: average return of last 100 episodes is -11.3
# iteration205: average return of last 100 episodes is -11.0
# iteration206: average return of last 100 episodes is -12.8
# iteration207: average return of last 100 episodes is -12.0
# iteration208: average return of last 100 episodes is -11.5
# iteration209: average return of last 100 episodes is -11.3
# iteration210: average return of last 100 episodes is -12.1
# iteration211: average return of last 100 episodes is -9.7
# iteration212: average return of last 100 episodes is -9.8
# iteration213: average return of last 100 episodes is -11.6
# iteration214: average return of last 100 episodes is -10.1
# iteration215: average return of last 100 episodes is -11.4
# iteration216: average return of last 100 episodes is -12.3
# iteration217: average return of last 100 episodes is -11.7
# iteration218: average return of last 100 episodes is -10.7
# iteration219: average return of last 100 episodes is -13.6
# iteration220: average return of last 100 episodes is -10.8
# iteration221: average return of last 100 episodes is -11.0
# iteration222: average return of last 100 episodes is -11.8
# iteration223: average return of last 100 episodes is -10.3
# iteration224: average return of last 100 episodes is -10.6
# iteration225: average return of last 100 episodes is -10.5
# iteration226: average return of last 100 episodes is -7.2
# iteration227: average return of last 100 episodes is -12.3
# iteration228: average return of last 100 episodes is -13.3
# iteration229: average return of last 100 episodes is -10.3
# iteration230: average return of last 100 episodes is -9.7
# iteration231: average return of last 100 episodes is -11.1
# iteration232: average return of last 100 episodes is -11.1
# iteration233: average return of last 100 episodes is -11.7
# iteration234: average return of last 100 episodes is -9.1
# iteration235: average return of last 100 episodes is -12.7
# iteration236: average return of last 100 episodes is -11.4
# iteration237: average return of last 100 episodes is -12.4
# iteration238: average return of last 100 episodes is -9.8
# iteration239: average return of last 100 episodes is -11.5
# iteration240: average return of last 100 episodes is -10.8
# iteration241: average return of last 100 episodes is -13.1
# iteration242: average return of last 100 episodes is -11.9
# iteration243: average return of last 100 episodes is -10.9
# iteration244: average return of last 100 episodes is -11.3
# iteration245: average return of last 100 episodes is -12.1
# iteration246: average return of last 100 episodes is -10.2
# iteration247: average return of last 100 episodes is -10.6
# iteration248: average return of last 100 episodes is -11.0
# iteration249: average return of last 100 episodes is -10.8
# iteration250: average return of last 100 episodes is -12.2
# iteration251: average return of last 100 episodes is -9.1
# iteration252: average return of last 100 episodes is -9.6
# iteration253: average return of last 100 episodes is -11.4
# iteration254: average return of last 100 episodes is -11.3
# iteration255: average return of last 100 episodes is -12.5
# iteration256: average return of last 100 episodes is -13.1
# iteration257: average return of last 100 episodes is -9.9
# iteration258: average return of last 100 episodes is -12.1
# iteration259: average return of last 100 episodes is -10.2
# iteration260: average return of last 100 episodes is -9.0
# iteration261: average return of last 100 episodes is -8.3
# iteration262: average return of last 100 episodes is -11.0
# iteration263: average return of last 100 episodes is -11.9
# iteration264: average return of last 100 episodes is -9.1
# iteration265: average return of last 100 episodes is -11.5
# iteration266: average return of last 100 episodes is -13.7
# iteration267: average return of last 100 episodes is -10.6
# iteration268: average return of last 100 episodes is -11.6
# iteration269: average return of last 100 episodes is -10.4
# iteration270: average return of last 100 episodes is -9.7
# iteration271: average return of last 100 episodes is -10.9
# iteration272: average return of last 100 episodes is -10.6
# iteration273: average return of last 100 episodes is -12.1
# iteration274: average return of last 100 episodes is -14.3
# iteration275: average return of last 100 episodes is -9.7
# iteration276: average return of last 100 episodes is -11.7
# iteration277: average return of last 100 episodes is -10.5
# iteration278: average return of last 100 episodes is -9.0
# iteration279: average return of last 100 episodes is -10.1
# iteration280: average return of last 100 episodes is -10.6
# iteration281: average return of last 100 episodes is -10.7
# iteration282: average return of last 100 episodes is -10.4
# iteration283: average return of last 100 episodes is -11.4
# iteration284: average return of last 100 episodes is -11.8
# iteration285: average return of last 100 episodes is -7.3
# iteration286: average return of last 100 episodes is -11.2
# iteration287: average return of last 100 episodes is -11.1
# iteration288: average return of last 100 episodes is -11.2
# iteration289: average return of last 100 episodes is -12.5
# iteration290: average return of last 100 episodes is -12.0
# iteration291: average return of last 100 episodes is -11.2
# iteration292: average return of last 100 episodes is -9.1
# iteration293: average return of last 100 episodes is -12.4
# iteration294: average return of last 100 episodes is -12.5
# iteration295: average return of last 100 episodes is -12.9
# iteration296: average return of last 100 episodes is -10.1
# iteration297: average return of last 100 episodes is -10.7
# iteration298: average return of last 100 episodes is -11.0
# iteration299: average return of last 100 episodes is -10.9
# iteration300: average return of last 100 episodes is -11.1
# iteration301: average return of last 100 episodes is -9.8
# iteration302: average return of last 100 episodes is -10.2
# iteration303: average return of last 100 episodes is -9.9
# iteration304: average return of last 100 episodes is -12.2
# iteration305: average return of last 100 episodes is -10.9
# iteration306: average return of last 100 episodes is -9.1
# iteration307: average return of last 100 episodes is -9.5
# iteration308: average return of last 100 episodes is -11.1
# iteration309: average return of last 100 episodes is -11.5
# iteration310: average return of last 100 episodes is -10.4
# iteration311: average return of last 100 episodes is -12.3
# iteration312: average return of last 100 episodes is -12.8
# iteration313: average return of last 100 episodes is -10.1
# iteration314: average return of last 100 episodes is -10.9
# iteration315: average return of last 100 episodes is -8.6
# iteration316: average return of last 100 episodes is -10.3
# iteration317: average return of last 100 episodes is -10.1
# iteration318: average return of last 100 episodes is -10.7
# iteration319: average return of last 100 episodes is -8.4
# iteration320: average return of last 100 episodes is -12.3
# iteration321: average return of last 100 episodes is -15.1
# iteration322: average return of last 100 episodes is -11.4
# iteration323: average return of last 100 episodes is -11.9
# iteration324: average return of last 100 episodes is -12.0
# iteration325: average return of last 100 episodes is -12.1
# iteration326: average return of last 100 episodes is -10.5
# iteration327: average return of last 100 episodes is -11.0
# iteration328: average return of last 100 episodes is -12.1
# iteration329: average return of last 100 episodes is -12.3
# iteration330: average return of last 100 episodes is -12.9
# iteration331: average return of last 100 episodes is -12.0
# iteration332: average return of last 100 episodes is -9.1
# iteration333: average return of last 100 episodes is -13.2
# iteration334: average return of last 100 episodes is -13.4
# iteration335: average return of last 100 episodes is -10.7
# iteration336: average return of last 100 episodes is -12.7
# iteration337: average return of last 100 episodes is -10.8
# iteration338: average return of last 100 episodes is -10.8
# iteration339: average return of last 100 episodes is -11.8
# iteration340: average return of last 100 episodes is -10.5
# iteration341: average return of last 100 episodes is -10.4
# iteration342: average return of last 100 episodes is -11.8
# iteration343: average return of last 100 episodes is -12.2
# iteration344: average return of last 100 episodes is -12.7
# iteration345: average return of last 100 episodes is -10.3
# iteration346: average return of last 100 episodes is -11.2
# iteration347: average return of last 100 episodes is -12.8
# iteration348: average return of last 100 episodes is -11.8
# iteration349: average return of last 100 episodes is -12.5
# iteration350: average return of last 100 episodes is -12.8
# iteration351: average return of last 100 episodes is -14.0
# iteration352: average return of last 100 episodes is -14.9
# iteration353: average return of last 100 episodes is -13.8
# iteration354: average return of last 100 episodes is -11.7
# iteration355: average return of last 100 episodes is -12.1
# iteration356: average return of last 100 episodes is -12.0
# iteration357: average return of last 100 episodes is -10.3
# iteration358: average return of last 100 episodes is -12.0
# iteration359: average return of last 100 episodes is -11.9
# iteration360: average return of last 100 episodes is -12.3
# iteration361: average return of last 100 episodes is -13.1
# iteration362: average return of last 100 episodes is -11.2
# iteration363: average return of last 100 episodes is -12.3
# iteration364: average return of last 100 episodes is -11.2
# iteration365: average return of last 100 episodes is -12.0
# iteration366: average return of last 100 episodes is -12.0
# iteration367: average return of last 100 episodes is -12.7
# iteration368: average return of last 100 episodes is -12.9
# iteration369: average return of last 100 episodes is -11.6
# iteration370: average return of last 100 episodes is -14.0
# iteration371: average return of last 100 episodes is -13.0
# iteration372: average return of last 100 episodes is -12.8
# iteration373: average return of last 100 episodes is -13.2
# iteration374: average return of last 100 episodes is -13.3
# iteration375: average return of last 100 episodes is -13.0
# iteration376: average return of last 100 episodes is -12.6
# iteration377: average return of last 100 episodes is -12.8
# iteration378: average return of last 100 episodes is -14.2
# iteration379: average return of last 100 episodes is -14.4
# iteration380: average return of last 100 episodes is -12.2
# iteration381: average return of last 100 episodes is -14.7
# iteration382: average return of last 100 episodes is -11.8
# iteration383: average return of last 100 episodes is -12.1
# iteration384: average return of last 100 episodes is -12.0
# iteration385: average return of last 100 episodes is -12.3
# iteration386: average return of last 100 episodes is -13.5
# iteration387: average return of last 100 episodes is -11.8
# iteration388: average return of last 100 episodes is -10.2
# iteration389: average return of last 100 episodes is -11.4
# iteration390: average return of last 100 episodes is -12.0
# iteration391: average return of last 100 episodes is -12.9
# iteration392: average return of last 100 episodes is -10.2
# iteration393: average return of last 100 episodes is -10.1
# iteration394: average return of last 100 episodes is -12.7
# iteration395: average return of last 100 episodes is -11.6
# iteration396: average return of last 100 episodes is -11.7
# iteration397: average return of last 100 episodes is -10.5
# iteration398: average return of last 100 episodes is -12.4
# iteration399: average return of last 100 episodes is -12.1
# iteration400: average return of last 100 episodes is -11.5
# iteration401: average return of last 100 episodes is -12.0
# iteration402: average return of last 100 episodes is -13.0
# iteration403: average return of last 100 episodes is -10.9
# iteration404: average return of last 100 episodes is -9.9
# iteration405: average return of last 100 episodes is -8.8
# iteration406: average return of last 100 episodes is -12.7
# iteration407: average return of last 100 episodes is -11.7
# iteration408: average return of last 100 episodes is -12.3
# iteration409: average return of last 100 episodes is -10.0
# iteration410: average return of last 100 episodes is -10.5
# iteration411: average return of last 100 episodes is -10.7
# iteration412: average return of last 100 episodes is -11.1
# iteration413: average return of last 100 episodes is -10.9
# iteration414: average return of last 100 episodes is -10.5
# iteration415: average return of last 100 episodes is -12.0
# iteration416: average return of last 100 episodes is -12.3
# iteration417: average return of last 100 episodes is -11.2
# iteration418: average return of last 100 episodes is -11.5
# iteration419: average return of last 100 episodes is -11.2
# iteration420: average return of last 100 episodes is -12.2
# iteration421: average return of last 100 episodes is -10.2
# iteration422: average return of last 100 episodes is -11.9
# iteration423: average return of last 100 episodes is -11.4
# iteration424: average return of last 100 episodes is -11.1
# iteration425: average return of last 100 episodes is -12.6
# iteration426: average return of last 100 episodes is -10.9
# iteration427: average return of last 100 episodes is -12.7
# iteration428: average return of last 100 episodes is -11.3
# iteration429: average return of last 100 episodes is -11.7
# iteration430: average return of last 100 episodes is -11.0
# iteration431: average return of last 100 episodes is -9.2
# iteration432: average return of last 100 episodes is -9.9
# iteration433: average return of last 100 episodes is -12.5
# iteration434: average return of last 100 episodes is -11.5
# iteration435: average return of last 100 episodes is -11.5
# iteration436: average return of last 100 episodes is -12.4
# iteration437: average return of last 100 episodes is -9.9
# iteration438: average return of last 100 episodes is -10.3
# iteration439: average return of last 100 episodes is -11.7
# iteration440: average return of last 100 episodes is -10.0
# iteration441: average return of last 100 episodes is -8.2
# iteration442: average return of last 100 episodes is -11.2
# iteration443: average return of last 100 episodes is -11.7
# iteration444: average return of last 100 episodes is -8.7
# iteration445: average return of last 100 episodes is -11.7
# iteration446: average return of last 100 episodes is -10.0
# iteration447: average return of last 100 episodes is -11.2
# iteration448: average return of last 100 episodes is -12.6
# iteration449: average return of last 100 episodes is -13.7
# iteration450: average return of last 100 episodes is -9.3
# iteration451: average return of last 100 episodes is -10.8
# iteration452: average return of last 100 episodes is -8.9
# iteration453: average return of last 100 episodes is -11.7
# iteration454: average return of last 100 episodes is -11.6
# iteration455: average return of last 100 episodes is -11.2
# iteration456: average return of last 100 episodes is -9.7
# iteration457: average return of last 100 episodes is -12.2
# iteration458: average return of last 100 episodes is -13.2
# iteration459: average return of last 100 episodes is -11.1
# iteration460: average return of last 100 episodes is -12.0
# iteration461: average return of last 100 episodes is -11.7
# iteration462: average return of last 100 episodes is -10.5
# iteration463: average return of last 100 episodes is -10.6
# iteration464: average return of last 100 episodes is -8.0
# iteration465: average return of last 100 episodes is -9.5
# iteration466: average return of last 100 episodes is -11.2
# iteration467: average return of last 100 episodes is -9.3
# iteration468: average return of last 100 episodes is -12.6
# iteration469: average return of last 100 episodes is -11.2
# iteration470: average return of last 100 episodes is -11.1
# iteration471: average return of last 100 episodes is -11.9
# iteration472: average return of last 100 episodes is -10.7
# iteration473: average return of last 100 episodes is -8.8
# iteration474: average return of last 100 episodes is -11.7
# iteration475: average return of last 100 episodes is -11.0
# iteration476: average return of last 100 episodes is -12.7
# iteration477: average return of last 100 episodes is -11.2
# iteration478: average return of last 100 episodes is -11.3
# iteration479: average return of last 100 episodes is -11.6
# iteration480: average return of last 100 episodes is -11.8
# iteration481: average return of last 100 episodes is -10.9
# iteration482: average return of last 100 episodes is -13.1
# iteration483: average return of last 100 episodes is -11.5
# iteration484: average return of last 100 episodes is -10.4
# iteration485: average return of last 100 episodes is -13.4
# iteration486: average return of last 100 episodes is -8.3
# iteration487: average return of last 100 episodes is -11.4
# iteration488: average return of last 100 episodes is -9.3
# iteration489: average return of last 100 episodes is -10.0
# iteration490: average return of last 100 episodes is -11.2
# iteration491: average return of last 100 episodes is -10.8
# iteration492: average return of last 100 episodes is -9.2
# iteration493: average return of last 100 episodes is -10.0
# iteration494: average return of last 100 episodes is -10.7
# iteration495: average return of last 100 episodes is -10.6
# iteration496: average return of last 100 episodes is -10.7
# iteration497: average return of last 100 episodes is -11.3
# iteration498: average return of last 100 episodes is -9.0
# iteration499: average return of last 100 episodes is -8.5
# iteration500: average return of last 100 episodes is -10.3
# iteration501: average return of last 100 episodes is -9.7
# iteration502: average return of last 100 episodes is -9.1
# iteration503: average return of last 100 episodes is -10.8
# iteration504: average return of last 100 episodes is -10.8
# iteration505: average return of last 100 episodes is -10.3
# iteration506: average return of last 100 episodes is -11.5
# iteration507: average return of last 100 episodes is -11.1
# iteration508: average return of last 100 episodes is -9.9
# iteration509: average return of last 100 episodes is -10.2
# iteration510: average return of last 100 episodes is -11.1
# iteration511: average return of last 100 episodes is -10.8
# iteration512: average return of last 100 episodes is -11.6
# iteration513: average return of last 100 episodes is -12.0
# iteration514: average return of last 100 episodes is -9.4
# iteration515: average return of last 100 episodes is -9.1
# iteration516: average return of last 100 episodes is -11.3
# iteration517: average return of last 100 episodes is -12.3
# iteration518: average return of last 100 episodes is -11.1
# iteration519: average return of last 100 episodes is -10.6
# iteration520: average return of last 100 episodes is -12.8
# iteration521: average return of last 100 episodes is -9.9
# iteration522: average return of last 100 episodes is -9.7
# iteration523: average return of last 100 episodes is -11.1
# iteration524: average return of last 100 episodes is -10.7
# iteration525: average return of last 100 episodes is -11.1
# iteration526: average return of last 100 episodes is -11.3
# iteration527: average return of last 100 episodes is -11.2
# iteration528: average return of last 100 episodes is -11.0
# iteration529: average return of last 100 episodes is -11.4
# iteration530: average return of last 100 episodes is -9.5
# iteration531: average return of last 100 episodes is -11.4
# iteration532: average return of last 100 episodes is -10.7
# iteration533: average return of last 100 episodes is -10.3
# iteration534: average return of last 100 episodes is -10.4
# iteration535: average return of last 100 episodes is -9.2
# iteration536: average return of last 100 episodes is -10.4
# iteration537: average return of last 100 episodes is -8.7
# iteration538: average return of last 100 episodes is -11.0
# iteration539: average return of last 100 episodes is -12.1
# iteration540: average return of last 100 episodes is -11.9
# iteration541: average return of last 100 episodes is -9.0
# iteration542: average return of last 100 episodes is -10.2
# iteration543: average return of last 100 episodes is -11.6
# iteration544: average return of last 100 episodes is -10.9
# iteration545: average return of last 100 episodes is -12.6
# iteration546: average return of last 100 episodes is -12.0
# iteration547: average return of last 100 episodes is -10.8
# iteration548: average return of last 100 episodes is -10.4
# iteration549: average return of last 100 episodes is -11.6
# iteration550: average return of last 100 episodes is -11.5
# iteration551: average return of last 100 episodes is -11.1
# iteration552: average return of last 100 episodes is -11.3
# iteration553: average return of last 100 episodes is -13.2
# iteration554: average return of last 100 episodes is -11.8
# iteration555: average return of last 100 episodes is -9.9
# iteration556: average return of last 100 episodes is -11.3
# iteration557: average return of last 100 episodes is -13.0
# iteration558: average return of last 100 episodes is -12.2
# iteration559: average return of last 100 episodes is -10.7
# iteration560: average return of last 100 episodes is -10.1
# iteration561: average return of last 100 episodes is -11.7
# iteration562: average return of last 100 episodes is -11.9
# iteration563: average return of last 100 episodes is -9.7
# iteration564: average return of last 100 episodes is -10.3
# iteration565: average return of last 100 episodes is -11.4
# iteration566: average return of last 100 episodes is -10.4
# iteration567: average return of last 100 episodes is -11.1
# iteration568: average return of last 100 episodes is -10.0
# iteration569: average return of last 100 episodes is -10.5
# iteration570: average return of last 100 episodes is -11.9
# iteration571: average return of last 100 episodes is -10.2
# iteration572: average return of last 100 episodes is -13.0
# iteration573: average return of last 100 episodes is -8.9
# iteration574: average return of last 100 episodes is -11.8
# iteration575: average return of last 100 episodes is -10.5
# iteration576: average return of last 100 episodes is -11.0
# iteration577: average return of last 100 episodes is -11.7
# iteration578: average return of last 100 episodes is -10.1
# iteration579: average return of last 100 episodes is -11.7
# iteration580: average return of last 100 episodes is -9.4
# iteration581: average return of last 100 episodes is -11.3
# iteration582: average return of last 100 episodes is -12.1
# iteration583: average return of last 100 episodes is -13.1
# iteration584: average return of last 100 episodes is -12.5
# iteration585: average return of last 100 episodes is -9.6
# iteration586: average return of last 100 episodes is -10.0
# iteration587: average return of last 100 episodes is -11.4
# iteration588: average return of last 100 episodes is -11.0
# iteration589: average return of last 100 episodes is -11.4
# iteration590: average return of last 100 episodes is -11.3
# iteration591: average return of last 100 episodes is -11.2
# iteration592: average return of last 100 episodes is -10.4
# iteration593: average return of last 100 episodes is -10.7
# iteration594: average return of last 100 episodes is -9.1
# iteration595: average return of last 100 episodes is -11.0
# iteration596: average return of last 100 episodes is -12.1
# iteration597: average return of last 100 episodes is -10.7
# iteration598: average return of last 100 episodes is -11.7
# iteration599: average return of last 100 episodes is -11.4
# iteration600: average return of last 100 episodes is -11.9
# iteration601: average return of last 100 episodes is -13.5
# iteration602: average return of last 100 episodes is -11.9
# iteration603: average return of last 100 episodes is -11.8
# iteration604: average return of last 100 episodes is -10.6
# iteration605: average return of last 100 episodes is -11.7
# iteration606: average return of last 100 episodes is -10.9
# iteration607: average return of last 100 episodes is -10.2
# iteration608: average return of last 100 episodes is -12.1
# iteration609: average return of last 100 episodes is -13.2
# iteration610: average return of last 100 episodes is -10.5
# iteration611: average return of last 100 episodes is -12.5
# iteration612: average return of last 100 episodes is -12.0
# iteration613: average return of last 100 episodes is -11.2
# iteration614: average return of last 100 episodes is -11.9
# iteration615: average return of last 100 episodes is -13.5
# iteration616: average return of last 100 episodes is -11.2
# iteration617: average return of last 100 episodes is -11.4
# iteration618: average return of last 100 episodes is -10.8
# iteration619: average return of last 100 episodes is -11.1
# iteration620: average return of last 100 episodes is -13.1
# iteration621: average return of last 100 episodes is -12.3
# iteration622: average return of last 100 episodes is -13.6
# iteration623: average return of last 100 episodes is -12.8
# iteration624: average return of last 100 episodes is -12.4
# iteration625: average return of last 100 episodes is -9.7
# iteration626: average return of last 100 episodes is -13.1
# iteration627: average return of last 100 episodes is -7.8
# iteration628: average return of last 100 episodes is -12.9
# iteration629: average return of last 100 episodes is -11.0
# iteration630: average return of last 100 episodes is -11.4
# iteration631: average return of last 100 episodes is -12.5
# iteration632: average return of last 100 episodes is -12.6
# iteration633: average return of last 100 episodes is -10.3
# iteration634: average return of last 100 episodes is -12.8
# iteration635: average return of last 100 episodes is -12.5
# iteration636: average return of last 100 episodes is -11.9
# iteration637: average return of last 100 episodes is -11.9
# iteration638: average return of last 100 episodes is -11.2
# iteration639: average return of last 100 episodes is -12.3
# iteration640: average return of last 100 episodes is -11.2
# iteration641: average return of last 100 episodes is -13.5
# iteration642: average return of last 100 episodes is -11.1
# iteration643: average return of last 100 episodes is -11.5
# iteration644: average return of last 100 episodes is -11.8
# iteration645: average return of last 100 episodes is -12.5
# iteration646: average return of last 100 episodes is -13.6
# iteration647: average return of last 100 episodes is -13.6
# iteration648: average return of last 100 episodes is -12.2
# iteration649: average return of last 100 episodes is -14.0
# iteration650: average return of last 100 episodes is -14.1
# iteration651: average return of last 100 episodes is -14.0
# iteration652: average return of last 100 episodes is -14.0
# iteration653: average return of last 100 episodes is -12.0
# iteration654: average return of last 100 episodes is -13.2
# iteration655: average return of last 100 episodes is -13.6
# iteration656: average return of last 100 episodes is -12.5
# iteration657: average return of last 100 episodes is -11.0
# iteration658: average return of last 100 episodes is -12.7
# iteration659: average return of last 100 episodes is -12.7
# iteration660: average return of last 100 episodes is -10.7
# iteration661: average return of last 100 episodes is -13.0
# iteration662: average return of last 100 episodes is -12.5
# iteration663: average return of last 100 episodes is -12.0
# iteration664: average return of last 100 episodes is -12.0
# iteration665: average return of last 100 episodes is -10.6
# iteration666: average return of last 100 episodes is -11.1
# iteration667: average return of last 100 episodes is -12.1
# iteration668: average return of last 100 episodes is -9.3
# iteration669: average return of last 100 episodes is -10.4
# iteration670: average return of last 100 episodes is -11.2
# iteration671: average return of last 100 episodes is -11.4
# iteration672: average return of last 100 episodes is -10.4
# iteration673: average return of last 100 episodes is -9.1
# iteration674: average return of last 100 episodes is -12.4
# iteration675: average return of last 100 episodes is -11.5
# iteration676: average return of last 100 episodes is -10.9
# iteration677: average return of last 100 episodes is -11.8
# iteration678: average return of last 100 episodes is -11.0
# iteration679: average return of last 100 episodes is -9.5
# iteration680: average return of last 100 episodes is -9.8
# iteration681: average return of last 100 episodes is -9.9
# iteration682: average return of last 100 episodes is -11.6
# iteration683: average return of last 100 episodes is -14.0
# iteration684: average return of last 100 episodes is -14.7
# iteration685: average return of last 100 episodes is -12.6
# iteration686: average return of last 100 episodes is -13.2
# iteration687: average return of last 100 episodes is -14.0
# iteration688: average return of last 100 episodes is -11.8
# iteration689: average return of last 100 episodes is -13.7
# iteration690: average return of last 100 episodes is -12.7
# iteration691: average return of last 100 episodes is -11.7
# iteration692: average return of last 100 episodes is -13.2
# iteration693: average return of last 100 episodes is -12.9
# iteration694: average return of last 100 episodes is -12.2
# iteration695: average return of last 100 episodes is -11.3
# iteration696: average return of last 100 episodes is -11.7
# iteration697: average return of last 100 episodes is -11.1
# iteration698: average return of last 100 episodes is -10.6
# iteration699: average return of last 100 episodes is -11.7
# iteration700: average return of last 100 episodes is -12.0
# iteration701: average return of last 100 episodes is -10.9
# iteration702: average return of last 100 episodes is -12.8
# iteration703: average return of last 100 episodes is -11.5
# iteration704: average return of last 100 episodes is -11.9
# iteration705: average return of last 100 episodes is -11.0
# iteration706: average return of last 100 episodes is -13.2
# iteration707: average return of last 100 episodes is -8.0
# iteration708: average return of last 100 episodes is -10.8
# iteration709: average return of last 100 episodes is -12.0
# iteration710: average return of last 100 episodes is -12.9
# iteration711: average return of last 100 episodes is -11.3
# iteration712: average return of last 100 episodes is -10.6
# iteration713: average return of last 100 episodes is -13.1
# iteration714: average return of last 100 episodes is -10.4
# iteration715: average return of last 100 episodes is -9.3
# iteration716: average return of last 100 episodes is -11.7
# iteration717: average return of last 100 episodes is -12.4
# iteration718: average return of last 100 episodes is -12.1
# iteration719: average return of last 100 episodes is -10.8
# iteration720: average return of last 100 episodes is -11.6
# iteration721: average return of last 100 episodes is -9.0
# iteration722: average return of last 100 episodes is -8.5
# iteration723: average return of last 100 episodes is -12.0
# iteration724: average return of last 100 episodes is -10.4
# iteration725: average return of last 100 episodes is -10.4
# iteration726: average return of last 100 episodes is -11.9
# iteration727: average return of last 100 episodes is -10.8
# iteration728: average return of last 100 episodes is -10.3
# iteration729: average return of last 100 episodes is -12.4
# iteration730: average return of last 100 episodes is -11.1
# iteration731: average return of last 100 episodes is -13.0
# iteration732: average return of last 100 episodes is -13.4
# iteration733: average return of last 100 episodes is -11.8
# iteration734: average return of last 100 episodes is -13.6
# iteration735: average return of last 100 episodes is -14.0
# iteration736: average return of last 100 episodes is -12.4
# iteration737: average return of last 100 episodes is -12.9
# iteration738: average return of last 100 episodes is -13.1
# iteration739: average return of last 100 episodes is -12.0
# iteration740: average return of last 100 episodes is -12.1
# iteration741: average return of last 100 episodes is -11.2
# iteration742: average return of last 100 episodes is -12.3
# iteration743: average return of last 100 episodes is -8.9
# iteration744: average return of last 100 episodes is -12.3
# iteration745: average return of last 100 episodes is -11.1
# iteration746: average return of last 100 episodes is -12.0
# iteration747: average return of last 100 episodes is -12.9
# iteration748: average return of last 100 episodes is -11.9
# iteration749: average return of last 100 episodes is -10.4
# iteration750: average return of last 100 episodes is -13.8
# iteration751: average return of last 100 episodes is -11.5
# iteration752: average return of last 100 episodes is -12.1
# iteration753: average return of last 100 episodes is -11.3
# iteration754: average return of last 100 episodes is -12.4
# iteration755: average return of last 100 episodes is -11.8
# iteration756: average return of last 100 episodes is -10.3
# iteration757: average return of last 100 episodes is -11.0
# iteration758: average return of last 100 episodes is -10.8
# iteration759: average return of last 100 episodes is -13.5
# iteration760: average return of last 100 episodes is -11.6
# iteration761: average return of last 100 episodes is -13.2
# iteration762: average return of last 100 episodes is -13.9
# iteration763: average return of last 100 episodes is -13.9
# iteration764: average return of last 100 episodes is -12.0
# iteration765: average return of last 100 episodes is -10.0
# iteration766: average return of last 100 episodes is -12.6
# iteration767: average return of last 100 episodes is -12.0
# iteration768: average return of last 100 episodes is -13.0
# iteration769: average return of last 100 episodes is -11.6
# iteration770: average return of last 100 episodes is -12.7
# iteration771: average return of last 100 episodes is -13.4
# iteration772: average return of last 100 episodes is -13.3
# iteration773: average return of last 100 episodes is -13.9
# iteration774: average return of last 100 episodes is -12.9
# iteration775: average return of last 100 episodes is -12.5
# iteration776: average return of last 100 episodes is -10.3
# iteration777: average return of last 100 episodes is -13.0
# iteration778: average return of last 100 episodes is -12.4
# iteration779: average return of last 100 episodes is -11.2
# iteration780: average return of last 100 episodes is -11.3
# iteration781: average return of last 100 episodes is -12.6
# iteration782: average return of last 100 episodes is -11.8
# iteration783: average return of last 100 episodes is -12.0
# iteration784: average return of last 100 episodes is -12.4
# iteration785: average return of last 100 episodes is -12.3
# iteration786: average return of last 100 episodes is -13.1
# iteration787: average return of last 100 episodes is -14.1
# iteration788: average return of last 100 episodes is -13.2
# iteration789: average return of last 100 episodes is -11.6
# iteration790: average return of last 100 episodes is -13.0
# iteration791: average return of last 100 episodes is -11.9
# iteration792: average return of last 100 episodes is -11.6
# iteration793: average return of last 100 episodes is -13.0
# iteration794: average return of last 100 episodes is -11.2
# iteration795: average return of last 100 episodes is -10.9
# iteration796: average return of last 100 episodes is -13.0
# iteration797: average return of last 100 episodes is -12.1
# iteration798: average return of last 100 episodes is -12.5
# iteration799: average return of last 100 episodes is -14.9
# iteration800: average return of last 100 episodes is -14.3
# iteration801: average return of last 100 episodes is -13.3
# iteration802: average return of last 100 episodes is -12.8
# iteration803: average return of last 100 episodes is -13.7
# iteration804: average return of last 100 episodes is -13.4
# iteration805: average return of last 100 episodes is -13.4
# iteration806: average return of last 100 episodes is -16.4
# iteration807: average return of last 100 episodes is -14.7
# iteration808: average return of last 100 episodes is -14.3
# iteration809: average return of last 100 episodes is -14.6
# iteration810: average return of last 100 episodes is -13.9
# iteration811: average return of last 100 episodes is -13.5
# iteration812: average return of last 100 episodes is -12.6
# iteration813: average return of last 100 episodes is -14.2
# iteration814: average return of last 100 episodes is -13.1
# iteration815: average return of last 100 episodes is -12.9
# ...
# iteration1242: average return of last 100 episodes is -12.9
# iteration1243: average return of last 100 episodes is -10.3
# iteration1244: average return of last 100 episodes is -11.3
# iteration1245: average return of last 100 episodes is -11.7
# iteration1246: average return of last 100 episodes is -11.8
# iteration1247: average return of last 100 episodes is -13.6
# iteration1248: average return of last 100 episodes is -11.7
# iteration1249: average return of last 100 episodes is -12.1
# iteration1250: average return of last 100 episodes is -10.3
# iteration1251: average return of last 100 episodes is -12.2
# iteration1252: average return of last 100 episodes is -9.8
# iteration1253: average return of last 100 episodes is -9.8
# iteration1254: average return of last 100 episodes is -11.3
# iteration1255: average return of last 100 episodes is -10.9
# iteration1256: average return of last 100 episodes is -12.9
# iteration1257: average return of last 100 episodes is -9.8
# iteration1258: average return of last 100 episodes is -9.9
# iteration1259: average return of last 100 episodes is -7.7
# iteration1260: average return of last 100 episodes is -10.7
# iteration1261: average return of last 100 episodes is -8.5
# iteration1262: average return of last 100 episodes is -11.4
# iteration1263: average return of last 100 episodes is -8.4
# iteration1264: average return of last 100 episodes is -11.5
# iteration1265: average return of last 100 episodes is -11.9
# iteration1266: average return of last 100 episodes is -9.8
# iteration1267: average return of last 100 episodes is -9.9
# iteration1268: average return of last 100 episodes is -9.9
# iteration1269: average return of last 100 episodes is -10.9
# iteration1270: average return of last 100 episodes is -11.0
# iteration1271: average return of last 100 episodes is -9.1
# iteration1272: average return of last 100 episodes is -12.7
# iteration1273: average return of last 100 episodes is -12.4
# iteration1274: average return of last 100 episodes is -9.6
# iteration1275: average return of last 100 episodes is -11.1
# iteration1276: average return of last 100 episodes is -8.8
# iteration1277: average return of last 100 episodes is -9.6
# iteration1278: average return of last 100 episodes is -9.3
# iteration1279: average return of last 100 episodes is -9.6
# iteration1280: average return of last 100 episodes is -10.4
# iteration1281: average return of last 100 episodes is -11.4
# iteration1282: average return of last 100 episodes is -11.9
# iteration1283: average return of last 100 episodes is -13.0
# iteration1284: average return of last 100 episodes is -12.8
# iteration1285: average return of last 100 episodes is -11.7
# iteration1286: average return of last 100 episodes is -10.0
# iteration1287: average return of last 100 episodes is -10.5
# iteration1288: average return of last 100 episodes is -10.0
# iteration1289: average return of last 100 episodes is -10.8
# iteration1290: average return of last 100 episodes is -11.0
# iteration1291: average return of last 100 episodes is -9.1
# iteration1292: average return of last 100 episodes is -10.7
# iteration1293: average return of last 100 episodes is -10.0
# iteration1294: average return of last 100 episodes is -9.4
# iteration1295: average return of last 100 episodes is -9.9
# iteration1296: average return of last 100 episodes is -8.8
# iteration1297: average return of last 100 episodes is -8.6
# iteration1298: average return of last 100 episodes is -9.8
# iteration1299: average return of last 100 episodes is -10.5
# iteration1300: average return of last 100 episodes is -10.5
# iteration1301: average return of last 100 episodes is -12.7
# iteration1302: average return of last 100 episodes is -10.6
# iteration1303: average return of last 100 episodes is -8.8
# iteration1304: average return of last 100 episodes is -11.5
# iteration1305: average return of last 100 episodes is -10.2
# iteration1306: average return of last 100 episodes is -10.1
# iteration1307: average return of last 100 episodes is -9.1
# iteration1308: average return of last 100 episodes is -11.0
# iteration1309: average return of last 100 episodes is -10.4
# iteration1310: average return of last 100 episodes is -8.5
# iteration1311: average return of last 100 episodes is -11.0
# iteration1312: average return of last 100 episodes is -8.7
# iteration1313: average return of last 100 episodes is -9.3
# iteration1314: average return of last 100 episodes is -11.3
# iteration1315: average return of last 100 episodes is -10.6
# iteration1316: average return of last 100 episodes is -10.7
# iteration1317: average return of last 100 episodes is -10.4
# iteration1318: average return of last 100 episodes is -10.8
# iteration1319: average return of last 100 episodes is -11.9
# iteration1320: average return of last 100 episodes is -10.8
# iteration1321: average return of last 100 episodes is -9.4
# iteration1322: average return of last 100 episodes is -10.7
# iteration1323: average return of last 100 episodes is -12.3
# iteration1324: average return of last 100 episodes is -10.3
# iteration1325: average return of last 100 episodes is -10.9
# iteration1326: average return of last 100 episodes is -9.4
# iteration1327: average return of last 100 episodes is -9.6
# iteration1328: average return of last 100 episodes is -11.8
# iteration1329: average return of last 100 episodes is -12.3
# iteration1330: average return of last 100 episodes is -10.6
# iteration1331: average return of last 100 episodes is -9.9
# iteration1332: average return of last 100 episodes is -10.6
# iteration1333: average return of last 100 episodes is -11.3
# iteration1334: average return of last 100 episodes is -10.9
# iteration1335: average return of last 100 episodes is -10.8
# iteration1336: average return of last 100 episodes is -12.2
# iteration1337: average return of last 100 episodes is -11.9
# iteration1338: average return of last 100 episodes is -9.8
# iteration1339: average return of last 100 episodes is -9.7
# iteration1340: average return of last 100 episodes is -11.4
# iteration1341: average return of last 100 episodes is -8.0
# iteration1342: average return of last 100 episodes is -9.3
# iteration1343: average return of last 100 episodes is -8.8
# iteration1344: average return of last 100 episodes is -8.7
# iteration1345: average return of last 100 episodes is -10.1
# iteration1346: average return of last 100 episodes is -11.8
# iteration1347: average return of last 100 episodes is -8.7
# iteration1348: average return of last 100 episodes is -11.7
# iteration1349: average return of last 100 episodes is -10.3
# iteration1350: average return of last 100 episodes is -8.6
# iteration1351: average return of last 100 episodes is -11.1
# iteration1352: average return of last 100 episodes is -10.1
# iteration1353: average return of last 100 episodes is -8.4
# iteration1354: average return of last 100 episodes is -7.5
# iteration1355: average return of last 100 episodes is -8.7
# iteration1356: average return of last 100 episodes is -9.5
# iteration1357: average return of last 100 episodes is -10.2
# iteration1358: average return of last 100 episodes is -10.1
# iteration1359: average return of last 100 episodes is -7.8
# iteration1360: average return of last 100 episodes is -12.2
# iteration1361: average return of last 100 episodes is -10.0
# iteration1362: average return of last 100 episodes is -10.4
# iteration1363: average return of last 100 episodes is -10.4
# iteration1364: average return of last 100 episodes is -8.4
# iteration1365: average return of last 100 episodes is -9.9
# iteration1366: average return of last 100 episodes is -10.7
# iteration1367: average return of last 100 episodes is -9.0
# iteration1368: average return of last 100 episodes is -10.5
# iteration1369: average return of last 100 episodes is -11.1
# iteration1370: average return of last 100 episodes is -7.7
# iteration1371: average return of last 100 episodes is -8.5
# iteration1372: average return of last 100 episodes is -10.7
# iteration1373: average return of last 100 episodes is -9.1
# iteration1374: average return of last 100 episodes is -11.8
# iteration1375: average return of last 100 episodes is -8.8
# iteration1376: average return of last 100 episodes is -9.9
# iteration1377: average return of last 100 episodes is -9.2
# iteration1378: average return of last 100 episodes is -7.9
# iteration1379: average return of last 100 episodes is -10.2
# iteration1380: average return of last 100 episodes is -8.1
# iteration1381: average return of last 100 episodes is -10.1
# iteration1382: average return of last 100 episodes is -10.9
# iteration1383: average return of last 100 episodes is -11.2
# iteration1384: average return of last 100 episodes is -10.2
# iteration1385: average return of last 100 episodes is -11.4
# iteration1386: average return of last 100 episodes is -8.3
# iteration1387: average return of last 100 episodes is -10.8
# iteration1388: average return of last 100 episodes is -12.2
# iteration1389: average return of last 100 episodes is -12.1
# iteration1390: average return of last 100 episodes is -11.0
# iteration1391: average return of last 100 episodes is -8.9
# iteration1392: average return of last 100 episodes is -11.3
# iteration1393: average return of last 100 episodes is -11.5
# iteration1394: average return of last 100 episodes is -11.1
# iteration1395: average return of last 100 episodes is -9.9
# iteration1396: average return of last 100 episodes is -7.5
# iteration1397: average return of last 100 episodes is -9.6
# iteration1398: average return of last 100 episodes is -8.8
# iteration1399: average return of last 100 episodes is -11.4
# iteration1400: average return of last 100 episodes is -7.2
# iteration1401: average return of last 100 episodes is -9.6
# iteration1402: average return of last 100 episodes is -11.9
# iteration1403: average return of last 100 episodes is -9.7
# iteration1404: average return of last 100 episodes is -9.4
# iteration1405: average return of last 100 episodes is -11.1
# iteration1406: average return of last 100 episodes is -10.0
# iteration1407: average return of last 100 episodes is -11.3
# iteration1408: average return of last 100 episodes is -11.4
# iteration1409: average return of last 100 episodes is -11.6
# iteration1410: average return of last 100 episodes is -9.1
# iteration1411: average return of last 100 episodes is -9.7
# iteration1412: average return of last 100 episodes is -9.3
# iteration1413: average return of last 100 episodes is -12.0
# iteration1414: average return of last 100 episodes is -9.3
# iteration1415: average return of last 100 episodes is -9.7
# iteration1416: average return of last 100 episodes is -9.8
# iteration1417: average return of last 100 episodes is -10.9
# iteration1418: average return of last 100 episodes is -8.0
# iteration1419: average return of last 100 episodes is -10.1
# iteration1420: average return of last 100 episodes is -10.1
# iteration1421: average return of last 100 episodes is -12.0
# iteration1422: average return of last 100 episodes is -10.4
# iteration1423: average return of last 100 episodes is -12.3
# iteration1424: average return of last 100 episodes is -11.3
# iteration1425: average return of last 100 episodes is -9.9
# iteration1426: average return of last 100 episodes is -10.9
# iteration1427: average return of last 100 episodes is -9.6
# iteration1428: average return of last 100 episodes is -10.7
# iteration1429: average return of last 100 episodes is -10.9
# iteration1430: average return of last 100 episodes is -9.7
# iteration1431: average return of last 100 episodes is -7.7
# iteration1432: average return of last 100 episodes is -10.8
# iteration1433: average return of last 100 episodes is -10.9
# iteration1434: average return of last 100 episodes is -12.3
# iteration1435: average return of last 100 episodes is -11.1
# iteration1436: average return of last 100 episodes is -9.5
# iteration1437: average return of last 100 episodes is -9.0
# iteration1438: average return of last 100 episodes is -10.1
# iteration1439: average return of last 100 episodes is -10.0
# iteration1440: average return of last 100 episodes is -11.8
# iteration1441: average return of last 100 episodes is -9.2
# iteration1442: average return of last 100 episodes is -11.4
# iteration1443: average return of last 100 episodes is -11.3
# iteration1444: average return of last 100 episodes is -12.6
# iteration1445: average return of last 100 episodes is -12.7
# iteration1446: average return of last 100 episodes is -12.2
# iteration1447: average return of last 100 episodes is -12.9
# iteration1448: average return of last 100 episodes is -11.6
# iteration1449: average return of last 100 episodes is -10.3
# iteration1450: average return of last 100 episodes is -11.4
# iteration1451: average return of last 100 episodes is -11.8
# iteration1452: average return of last 100 episodes is -10.7
# iteration1453: average return of last 100 episodes is -12.3
# iteration1454: average return of last 100 episodes is -13.3
# iteration1455: average return of last 100 episodes is -13.8
# iteration1456: average return of last 100 episodes is -9.5
# iteration1457: average return of last 100 episodes is -10.9
# iteration1458: average return of last 100 episodes is -10.3
# iteration1459: average return of last 100 episodes is -11.1
# iteration1460: average return of last 100 episodes is -10.1
# iteration1461: average return of last 100 episodes is -12.4
# iteration1462: average return of last 100 episodes is -12.8
# iteration1463: average return of last 100 episodes is -11.5
# iteration1464: average return of last 100 episodes is -10.3
# iteration1465: average return of last 100 episodes is -12.2
# iteration1466: average return of last 100 episodes is -11.4
# iteration1467: average return of last 100 episodes is -11.2
# iteration1468: average return of last 100 episodes is -13.1
# iteration1469: average return of last 100 episodes is -11.6
# iteration1470: average return of last 100 episodes is -11.1
# iteration1471: average return of last 100 episodes is -11.0
# iteration1472: average return of last 100 episodes is -10.2
# iteration1473: average return of last 100 episodes is -12.0
# iteration1474: average return of last 100 episodes is -10.6
# iteration1475: average return of last 100 episodes is -11.4
# iteration1476: average return of last 100 episodes is -11.0
# iteration1477: average return of last 100 episodes is -12.7
# iteration1478: average return of last 100 episodes is -10.7
# iteration1479: average return of last 100 episodes is -11.3
# iteration1480: average return of last 100 episodes is -9.9
# iteration1481: average return of last 100 episodes is -11.1
# iteration1482: average return of last 100 episodes is -13.6
# iteration1483: average return of last 100 episodes is -11.5
# iteration1484: average return of last 100 episodes is -11.5
# iteration1485: average return of last 100 episodes is -10.5
# iteration1486: average return of last 100 episodes is -12.0
# iteration1487: average return of last 100 episodes is -12.4
# iteration1488: average return of last 100 episodes is -12.3
# iteration1489: average return of last 100 episodes is -10.5
# iteration1490: average return of last 100 episodes is -11.9
# iteration1491: average return of last 100 episodes is -12.6
# iteration1492: average return of last 100 episodes is -11.3
# iteration1493: average return of last 100 episodes is -11.6
# iteration1494: average return of last 100 episodes is -9.4
# iteration1495: average return of last 100 episodes is -12.2
# iteration1496: average return of last 100 episodes is -11.8
# iteration1497: average return of last 100 episodes is -10.6
# iteration1498: average return of last 100 episodes is -12.2
# iteration1499: average return of last 100 episodes is -12.0
# iteration1500: average return of last 100 episodes is -13.5
# iteration1501: average return of last 100 episodes is -12.6
# iteration1502: average return of last 100 episodes is -12.7
# iteration1503: average return of last 100 episodes is -12.0
# iteration1504: average return of last 100 episodes is -13.6
# iteration1505: average return of last 100 episodes is -12.6
# iteration1506: average return of last 100 episodes is -11.0
# iteration1507: average return of last 100 episodes is -12.4
# iteration1508: average return of last 100 episodes is -8.8
# iteration1509: average return of last 100 episodes is -10.5

# %%
agent.save()

episodes_list = list(range(len(return_list)))
plt.plot(episodes_list, return_list)
plt.xlabel('Episodes')
plt.ylabel('Returns')
plt.title('PPO on {}'.format(env_name))
plt.show()

mv_return = moving_average(return_list, 9)
plt.plot(episodes_list, mv_return)
plt.xlabel('Episodes')
plt.ylabel('Returns')
plt.title('PPO on {}'.format(env_name))
plt.show()

# %%
 # 渲染模型的表现
import time
num_episodes = 20  # 渲染的轮次
for episode in range(num_episodes):
    state = env.reset()
    done = False
    while not done:
        env.render()  # 渲染当前环境
        time.sleep(0.005)
        state=state.astype(np.float32)
        state/=255
        action = agent.take_action(state)  # 使用训练好的代理选择动作
        state, reward, done, _ = env.step(action)  # 执行动作
        # print(reward)
    print(f"Episode {episode + 1} finished.")

env.close()  # 关闭环境
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       3 num_episodes = 20  # 渲染的轮次
#       4 for episode in range(num_episodes):
# ----> 5    state = env.reset()
#       6    done = False
#       7    while not done:
#
# NameError: name 'env' is not defined
